# %%
def compute_err_for_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        # [x, y] from dataset (csv file)
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m*x + b))**2
        return total_error / float(len(points))

# %%
def step_gradient(current_b, current_m, points, learning_rate):
    #gradient descent
    gradient_b = 0
    gradient_m = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        gradient_b += -(2/N) * (y - ((current_m * x) + current_b))
        gradient_m += -(2/N) * x * (y - ((current_m * x) + current_b))
        new_b = current_b - (learning_rate * gradient_b)
        new_m = current_m - (learning_rate * gradient_m)
    
    return [new_b, new_m]

# %% [markdown]
# The error (RSS) decreases for each iteration.

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations, acceptable_err):
    b = starting_b
    m = starting_m
    current_err = compute_err_for_points(b, m, points)
    i = 0
    while (acceptable_err <= current_err and i < num_iterations):
        b, m = step_gradient(b, m, array(points), learning_rate)
        gradient_size = (b**2 + m**2)**0.5 #check this
        print(gradient_size)
        if (gradient_size <= acceptable_err): #check this
            break
            
        current_err = compute_err_for_points(b, m, points)
        print("Gradient descent partial with new b = {}, new m = {} and error = {} at iteration {}." \
                                    .format(b, m, current_err, i+1))
        i += 1

    return [b, m]

# %% [markdown]
# For b ~ -39 and m ~ 5, we set the `learning_rate = 0.00335` and the `num_iterations = 14000`. With this setup, we get b ~ -38.99 and m ~ 5.57.
#
# With a `learning_rate = 0.0008` and `num_iterations = 14000`, we get b ~ -25.78 and m ~ 4.79 with an error of ~ 0.7. By using a tolerance (`acceptable_err = 0.00005`), we get b ~ -14.37 and m ~ 4.11, with only 6018 iterations.

# %%
def run():
    points = genfromtxt('income.csv', delimiter=',')
    #hyperparameters: 
    #too short --> too slow to converge
    #too great --> never converge
    learning_rate = 0.0008
    #y = mx + b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 14000
    acceptable_err = 0.00005
    initial_err = compute_err_for_points(initial_b, initial_m, points)
    print("Starting gradient descent with b = {}, m = {} and error = {}".format(initial_b, initial_m, initial_err))
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations, acceptable_err)
    print("Gradient descent finished with b = {}, m = {} and error = {}".format(b, m, compute_err_for_points(b, m, points)))

# %%
from numpy import *

if __name__ == '__main__':
    run()
# Out:
# Starting gradient descent with b = 0, m = 0 and error = 23.689789509379533
# 1.40095900009
# Gradient descent partial with new b = 0.08023275089091605, new m = 1.3986596532450708 and error = 5.285290108351334 at iteration 1.
# 2.19719720119
# Gradient descent partial with new b = 0.12453144225733284, new m = 2.1936653028179314 and error = 0.7046141727289403 at iteration 2.
# 2.64974347798
# Gradient descent partial with new b = 0.14840711108849813, new m = 2.6455842130784433 and error = 9.933393494608196e-05 at iteration 3.
# 2.90695366774
# Gradient descent partial with new b = 0.16067545474686445, new m = 2.9025097802786615 and error = 0.21284659454558857 at iteration 4.
# 3.0531458512
# Gradient descent partial with new b = 0.1663468745350518, new m = 3.0486108813778547 and error = 0.5316325327633656 at iteration 5.
# 3.13624222346
# Gradient descent partial with new b = 0.1682690318634387, new m = 3.131724894867604 and error = 0.7765610690574505 at iteration 6.
# 3.18347936176
# Gradient descent partial with new b = 0.16806039499476258, new m = 3.17904019326321 and error = 0.9362003236703794 at iteration 7.
# 3.21033716494
# Gradient descent partial with new b = 0.16664082030614885, new m = 3.206009287202772 and error = 1.0333817905499525 at iteration 8.
# 3.22561362179
# Gradient descent partial with new b = 0.1645331081321841, new m = 3.221414610606949 and error = 1.0905524851129473 at iteration 9.
# 3.23430905851
# Gradient descent partial with new b = 0.1620343920185508, new m = 3.2302476595102774 and error = 1.1235276578870241 at iteration 10.
# 3.23926540186
# Gradient descent partial with new b = 0.15931354779877407, new m = 3.2353453505226155 and error = 1.1422825395152836 at iteration 11.
# 3.24209785443
# Gradient descent partial with new b = 0.15646655603983314, new m = 3.2383200451076553 and error = 1.1528046865467234 at iteration 12.
# 3.243724412
# Gradient descent partial with new b = 0.1535479672863295, new m = 3.240088128851462 and error = 1.1585995672602052 at iteration 13.
# 3.2446668142
# Gradient descent partial with new b = 0.15058878533099002, new m = 3.2411704294726165 and error = 1.1616924210753505 at iteration 14.
# 3.24522158951
# Gradient descent partial with new b = 0.14760663117087752, new m = 3.2418629593885377 and error = 1.163244817774244 at iteration 15.
# 3.24555726832
# Gradient descent partial with new b = 0.14461151969157363, new m = 3.2423339572475167 and error = 1.1639202759052947 at iteration 16.
# 3.24576963375
# Gradient descent partial with new b = 0.14160914284544673, new m = 3.242679041480305 and error = 1.164096951469225 at iteration 17.
# 3.24591312332
# Gradient descent partial with new b = 0.13860273564591427, new m = 3.2429525568193664 and error = 1.1639900878639098 at iteration 18.
# 3.24601867592
# Gradient descent partial with new b = 0.1355941367052211, new m = 3.2431853900920853 and error = 1.1637221106222129 at iteration 19.
# 3.24610387517
# Gradient descent partial with new b = 0.13258439099105143, new m = 3.24339509582625 and error = 1.1633626237912735 at iteration 20.
# 3.24617871423
# Gradient descent partial with new b = 0.1295740924032298, new m = 3.2435916511376095 and error = 1.1629511908910286 at iteration 21.
# 3.24624887234
# Gradient descent partial with new b = 0.1265635784771779, new m = 3.2437807265200234 and error = 1.1625102971501635 at iteration 22.
# 3.24631757685
# Gradient descent partial with new b = 0.12355304104361788, new m = 3.2439655447989413 and error = 1.1620527206779243 at iteration 23.
# 3.2463866617
# Gradient descent partial with new b = 0.12054258912201124, new m = 3.24414793766755 and error = 1.1615857228160524 at iteration 24.
# 3.24645716881
# Gradient descent partial with new b = 0.1175322846660428, new m = 3.2443289461690616 and error = 1.16111342981905 at iteration 25.
# 3.24652968999
# Gradient descent partial with new b = 0.11452216287956522, new m = 3.2445091619807993 and error = 1.1606381863919357 at iteration 26.
# 3.24660456124
# Gradient descent partial with new b = 0.11151224376316551, new m = 3.2446889213829984 and error = 1.1601613248758016 at iteration 27.
# 3.24668197316
# Gradient descent partial with new b = 0.10850253867665575, new m = 3.2448684155009673 and error = 1.1596836023440062 at iteration 28.
# 3.2467620337
# Gradient descent partial with new b = 0.1054930540688644, new m = 3.2450477529612165 and error = 1.1592054489809003 at iteration 29.
# 3.24684480385
# Gradient descent partial with new b = 0.10248379359746314, new m = 3.2452269955020676 and error = 1.1587271092208176 at iteration 30.
# 3.2469303179
# Gradient descent partial with new b = 0.09947475933377033, new m = 3.245406178212941 and error = 1.15824872194855 at iteration 31.
# 3.24701859498
# Gradient descent partial with new b = 0.09646595244750107, new m = 3.245585321037355 and error = 1.1577703660720793 at iteration 32.
# 3.24710964555
# Gradient descent partial with new b = 0.09345737359594485, new m = 3.2457644353106563 and error = 1.1572920864185832 at iteration 33.
# 3.2472034752
# Gradient descent partial with new b = 0.0904490231451546, new m = 3.245943527475735 and error = 1.1568139084493938 at iteration 34.
# 3.24730008672
# Gradient descent partial with new b = 0.0874409012956596, new m = 3.2461226011948554 and error = 1.1563358466215314 at iteration 35.
# 3.2473994813
# Gradient descent partial with new b = 0.0844330081539143, new m = 3.2463016585499127 and error = 1.1558579091390289 at iteration 36.
# 3.24750165924
# Gradient descent partial with new b = 0.08142534377290633, new m = 3.2464807007245997 and error = 1.155380100652746 at iteration 37.
# 3.24760662031
# Gradient descent partial with new b = 0.07841790817523599, new m = 3.246659728392115 and error = 1.154902423794529 at iteration 38.
# 3.24771436398
# Gradient descent partial with new b = 0.07541070136623354, new m = 3.2468387419355187 and error = 1.1544248800489574 at iteration 39.
# 3.24782488956
# Gradient descent partial with new b = 0.07240372334141436, new m = 3.24701774157297 and error = 1.1539474702486856 at iteration 40.
# 3.24793819625
# Gradient descent partial with new b = 0.06939697409071612, new m = 3.247196727428907 and error = 1.1534701948559334 at iteration 41.
# 3.24805428318
# Gradient descent partial with new b = 0.066390453600907, new m = 3.247375699574502 and error = 1.152993054122438 at iteration 42.
# 3.24817314948
# Gradient descent partial with new b = 0.06338416185695438, new m = 3.247554658050652 and error = 1.152516048180313 at iteration 43.
# 3.24829479421
# Gradient descent partial with new b = 0.06037809884280263, new m = 3.2477336028810484 and error = 1.1520391770937286 at iteration 44.
# 3.24841921645
# Gradient descent partial with new b = 0.05737226454181537, new m = 3.247912534079603 and error = 1.1515624408882188 at iteration 45.
# 3.24854641523
# Gradient descent partial with new b = 0.054366658937026684, new m = 3.2480914516546706 and error = 1.1510858395673866 at iteration 46.
# 3.24867638961
# Gradient descent partial with new b = 0.05136128201128393, new m = 3.248270355611446 and error = 1.1506093731223717 at iteration 47.
# 3.24880913862
# Gradient descent partial with new b = 0.048356133747328924, new m = 3.2484492459533283 and error = 1.1501330415372226 at iteration 48.
# 3.24894466129
# Gradient descent partial with new b = 0.045351214127844056, new m = 3.248628122682697 and error = 1.14965684479197 at iteration 49.
# 3.24908295662
# Gradient descent partial with new b = 0.04234652313547853, new m = 3.2488069858013513 and error = 1.1491807828643663 at iteration 50.
# 3.24922402364
# Gradient descent partial with new b = 0.03934206075286323, new m = 3.248985835310761 and error = 1.1487048557308612 at iteration 51.
# 3.24936786134
# Gradient descent partial with new b = 0.03633782696261923, new m = 3.2491646712122075 and error = 1.1482290633671703 at iteration 52.
# 3.24951446873
# Gradient descent partial with new b = 0.03333382174736259, new m = 3.2493434935068666 and error = 1.1477534057485894 at iteration 53.
# 3.24966384479
# Gradient descent partial with new b = 0.03033004508970709, new m = 3.2495223021958535 and error = 1.1472778828501966 at iteration 54.
# 3.2498159885
# Gradient descent partial with new b = 0.027326496972265774, new m = 3.2497010972802483 and error = 1.1468024946469197 at iteration 55.
# 3.24997089884
# Gradient descent partial with new b = 0.02432317737765186, new m = 3.2498798787611123 and error = 1.1463272411136245 at iteration 56.
# 3.25012857479
# Gradient descent partial with new b = 0.021320086288479204, new m = 3.2500586466394945 and error = 1.14585212222513 at iteration 57.
# 3.2502890153
# Gradient descent partial with new b = 0.018317223687362647, new m = 3.2502374009164385 and error = 1.1453771379562465 at iteration 58.
# 3.25045221934
# Gradient descent partial with new b = 0.015314589556918105, new m = 3.250416141592984 and error = 1.1449022882817619 at iteration 59.
# 3.25061818584
# Gradient descent partial with new b = 0.01231218387976271, new m = 3.2505948686701682 and error = 1.1444275731764657 at iteration 60.
# 3.25078691375
# Gradient descent partial with new b = 0.009310006638514843, new m = 3.2507735821490273 and error = 1.1439529926151408 at iteration 61.
# 3.25095840202
# Gradient descent partial with new b = 0.006308057815794183, new m = 3.250952282030597 and error = 1.1434785465725847 at iteration 62.
# 3.25113264956
# Gradient descent partial with new b = 0.0033063373942216895, new m = 3.251130968315912 and error = 1.1430042350235883 at iteration 63.
# 3.2513096553
# Gradient descent partial with new b = 0.00030484535641964747, new m = 3.251309641006008 and error = 1.142530057942948 at iteration 64.
# 3.25148941815
# Gradient descent partial with new b = -0.0026964183149883587, new m = 3.251488300101918 and error = 1.1420560153054604 at iteration 65.
# 3.25167193704
# Gradient descent partial with new b = -0.005697453637377422, new m = 3.2516669456046774 and error = 1.141582107085933 at iteration 66.
# 3.25185721085
# Gradient descent partial with new b = -0.008698260628121297, new m = 3.2518455775153203 and error = 1.1411083332591698 at iteration 67.
# 3.25204523848
# Gradient descent partial with new b = -0.01169883930459244, new m = 3.2520241958348812 and error = 1.1406346937999894 at iteration 68.
# 3.25223601883
# Gradient descent partial with new b = -0.014699189684161994, new m = 3.2522028005643935 and error = 1.140161188683198 at iteration 69.
# 3.25242955077
# Gradient descent partial with new b = -0.017699311784199735, new m = 3.252381391704892 and error = 1.139687817883628 at iteration 70.
# 3.25262583319
# Gradient descent partial with new b = -0.020699205622074186, new m = 3.2525599692574096 and error = 1.1392145813760928 at iteration 71.
# 3.25282486495
# Gradient descent partial with new b = -0.023698871215152493, new m = 3.252738533222981 and error = 1.1387414791354227 at iteration 72.
# 3.25302664491
# Gradient descent partial with new b = -0.02669830858080049, new m = 3.2529170836026395 and error = 1.1382685111364583 at iteration 73.
# 3.25323117193
# Gradient descent partial with new b = -0.029697517736382725, new m = 3.253095620397419 and error = 1.1377956773540256 at iteration 74.
# 3.25343844486
# Gradient descent partial with new b = -0.032696498699262375, new m = 3.253274143608353 and error = 1.1373229777629745 at iteration 75.
# 3.25364846255
# Gradient descent partial with new b = -0.03569525148680133, new m = 3.253452653236475 and error = 1.1368504123381473 at iteration 76.
# 3.25386122382
# Gradient descent partial with new b = -0.03869377611636015, new m = 3.2536311492828185 and error = 1.13637798105439 at iteration 77.
# 3.25407672752
# Gradient descent partial with new b = -0.041692072605298065, new m = 3.253809631748417 and error = 1.135905683886561 at iteration 78.
# 3.25429497246
# Gradient descent partial with new b = -0.044690140970973, new m = 3.2539881006343037 and error = 1.1354335208095208 at iteration 79.
# 3.25451595746
# Gradient descent partial with new b = -0.04768798123074156, new m = 3.2541665559415116 and error = 1.1349614917981214 at iteration 80.
# 3.25473968133
# Gradient descent partial with new b = -0.05068559340195901, new m = 3.254344997671074 and error = 1.134489596827239 at iteration 81.
# 3.25496614288
# Gradient descent partial with new b = -0.0536829775019793, new m = 3.2545234258240234 and error = 1.1340178358717372 at iteration 82.
# 3.25519534091
# Gradient descent partial with new b = -0.05668013354815507, new m = 3.2547018404013937 and error = 1.1335462089064943 at iteration 83.
# 3.25542727419
# Gradient descent partial with new b = -0.05967706155783764, new m = 3.2548802414042175 and error = 1.1330747159063874 at iteration 84.
# 3.25566194153
# Gradient descent partial with new b = -0.06267376154837702, new m = 3.255058628833527 and error = 1.1326033568462999 at iteration 85.
# 3.2558993417
# Gradient descent partial with new b = -0.06567023353712184, new m = 3.2552370026903557 and error = 1.1321321317011224 at iteration 86.
# 3.25613947346
# Gradient descent partial with new b = -0.06866647754141948, new m = 3.255415362975736 and error = 1.131661040445738 at iteration 87.
# 3.25638233559
# Gradient descent partial with new b = -0.07166249357861598, new m = 3.2555937096907 and error = 1.1311900830550505 at iteration 88.
# 3.25662792685
# Gradient descent partial with new b = -0.07465828166605606, new m = 3.255772042836281 and error = 1.1307192595039568 at iteration 89.
# 3.25687624598
# Gradient descent partial with new b = -0.0776538418210831, new m = 3.255950362413511 and error = 1.1302485697673579 at iteration 90.
# 3.25712729174
# Gradient descent partial with new b = -0.08064917406103919, new m = 3.2561286684234227 and error = 1.1297780138201667 at iteration 91.
# 3.25738106286
# Gradient descent partial with new b = -0.08364427840326509, new m = 3.2563069608670476 and error = 1.1293075916372914 at iteration 92.
# 3.25763755808
# Gradient descent partial with new b = -0.08663915486510022, new m = 3.2564852397454183 and error = 1.128837303193648 at iteration 93.
# 3.25789677613
# Gradient descent partial with new b = -0.08963380346388271, new m = 3.256663505059567 and error = 1.1283671484641637 at iteration 94.
# 3.25815871572
# Gradient descent partial with new b = -0.09262822421694936, new m = 3.256841756810526 and error = 1.1278971274237568 at iteration 95.
# 3.25842337557
# Gradient descent partial with new b = -0.09562241714163563, new m = 3.2570199949993266 and error = 1.1274272400473597 at iteration 96.
# 3.2586907544
# Gradient descent partial with new b = -0.09861638225527572, new m = 3.257198219627001 and error = 1.1269574863099014 at iteration 97.
# 3.25896085089
# Gradient descent partial with new b = -0.10161011957520244, new m = 3.2573764306945807 and error = 1.1264878661863196 at iteration 98.
# 3.25923366375
# Gradient descent partial with new b = -0.10460362911874732, new m = 3.257554628203098 and error = 1.1260183796515617 at iteration 99.
# 3.25950919168
# Gradient descent partial with new b = -0.10759691090324057, new m = 3.257732812153584 and error = 1.125549026680568 at iteration 100.
# 3.25978743334
# Gradient descent partial with new b = -0.11058996494601107, new m = 3.2579109825470702 and error = 1.125079807248292 at iteration 101.
# 3.26006838742
# Gradient descent partial with new b = -0.11358279126438639, new m = 3.2580891393845883 and error = 1.1246107213296814 at iteration 102.
# 3.26035205259
# Gradient descent partial with new b = -0.11657538987569277, new m = 3.2582672826671697 and error = 1.1241417688996997 at iteration 103.
# 3.26063842751
# Gradient descent partial with new b = -0.11956776079725515, new m = 3.258445412395846 and error = 1.1236729499333087 at iteration 104.
# 3.26092751085
# Gradient descent partial with new b = -0.12255990404639713, new m = 3.258623528571648 and error = 1.1232042644054714 at iteration 105.
# 3.26121930126
# Gradient descent partial with new b = -0.12555181964044101, new m = 3.258801631195607 and error = 1.122735712291163 at iteration 106.
# 3.26151379738
# Gradient descent partial with new b = -0.1285435075967078, new m = 3.2589797202687545 and error = 1.122267293565357 at iteration 107.
# 3.26181099784
# Gradient descent partial with new b = -0.13153496793251712, new m = 3.2591577957921207 and error = 1.1217990082030342 at iteration 108.
# 3.2621109013
# Gradient descent partial with new b = -0.13452620066518733, new m = 3.2593358577667373 and error = 1.1213308561791735 at iteration 109.
# 3.26241350637
# Gradient descent partial with new b = -0.13751720581203544, new m = 3.2595139061936345 and error = 1.1208628374687601 at iteration 110.
# 3.26271881168
# Gradient descent partial with new b = -0.14050798339037718, new m = 3.2596919410738434 and error = 1.1203949520467946 at iteration 111.
# 3.26302681584
# Gradient descent partial with new b = -0.1434985334175269, new m = 3.259869962408395 and error = 1.1199271998882654 at iteration 112.
# 3.26333751747
# Gradient descent partial with new b = -0.14648885591079772, new m = 3.260047970198319 and error = 1.1194595809681749 at iteration 113.
# 3.26365091516
# Gradient descent partial with new b = -0.14947895088750135, new m = 3.2602259644446465 and error = 1.1189920952615249 at iteration 114.
# 3.26396700751
# Gradient descent partial with new b = -0.15246881836494824, new m = 3.260403945148408 and error = 1.118524742743326 at iteration 115.
# 3.26428579312
# Gradient descent partial with new b = -0.1554584583604475, new m = 3.2605819123106343 and error = 1.1180575233885903 at iteration 116.
# 3.26460727057
# Gradient descent partial with new b = -0.15844787089130696, new m = 3.260759865932355 and error = 1.1175904371723342 at iteration 117.
# 3.26493143844
# Gradient descent partial with new b = -0.1614370559748331, new m = 3.2609378060146 and error = 1.1171234840695743 at iteration 118.
# 3.26525829531
# Gradient descent partial with new b = -0.16442601362833106, new m = 3.2611157325584004 and error = 1.1166566640553435 at iteration 119.
# 3.26558783974
# Gradient descent partial with new b = -0.1674147438691047, new m = 3.261293645564786 and error = 1.1161899771046635 at iteration 120.
# 3.2659200703
# Gradient descent partial with new b = -0.1704032467144566, new m = 3.2614715450347864 and error = 1.1157234231925721 at iteration 121.
# 3.26625498553
# Gradient descent partial with new b = -0.17339152218168796, new m = 3.261649430969432 and error = 1.115257002294102 at iteration 122.
# 3.266592584
# Gradient descent partial with new b = -0.17637957028809867, new m = 3.261827303369752 and error = 1.1147907143842988 at iteration 123.
# 3.26693286424
# Gradient descent partial with new b = -0.17936739105098728, new m = 3.2620051622367767 and error = 1.1143245594382059 at iteration 124.
# 3.26727582479
# Gradient descent partial with new b = -0.18235498448765114, new m = 3.2621830075715352 and error = 1.1138585374308712 at iteration 125.
# 3.26762146419
# Gradient descent partial with new b = -0.18534235061538615, new m = 3.262360839375058 and error = 1.113392648337354 at iteration 126.
# 3.26796978096
# Gradient descent partial with new b = -0.18832948945148695, new m = 3.2625386576483737 and error = 1.1129268921327051 at iteration 127.
# 3.26832077362
# Gradient descent partial with new b = -0.19131640101324687, new m = 3.2627164623925125 and error = 1.1124612687919972 at iteration 128.
# 3.26867444069
# Gradient descent partial with new b = -0.19430308531795792, new m = 3.2628942536085033 and error = 1.1119957782902885 at iteration 129.
# 3.26903078067
# Gradient descent partial with new b = -0.19728954238291083, new m = 3.263072031297375 and error = 1.1115304206026464 at iteration 130.
# 3.26938979207
# Gradient descent partial with new b = -0.20027577222539492, new m = 3.263249795460158 and error = 1.1110651957041529 at iteration 131.
# 3.26975147339
# Gradient descent partial with new b = -0.20326177486269825, new m = 3.26342754609788 and error = 1.1106001035698863 at iteration 132.
# 3.27011582312
# Gradient descent partial with new b = -0.2062475503121076, new m = 3.263605283211571 and error = 1.1101351441749256 at iteration 133.
# 3.27048283974
# Gradient descent partial with new b = -0.20923309859090838, new m = 3.2637830068022597 and error = 1.1096703174943598 at iteration 134.
# 3.27085252174
# Gradient descent partial with new b = -0.21221841971638472, new m = 3.263960716870975 and error = 1.1092056235032814 at iteration 135.
# 3.27122486758
# Gradient descent partial with new b = -0.21520351370581942, new m = 3.264138413418746 and error = 1.1087410621767866 at iteration 136.
# 3.27159987574
# Gradient descent partial with new b = -0.21818838057649395, new m = 3.2643160964466005 and error = 1.108276633489968 at iteration 137.
# 3.27197754468
# Gradient descent partial with new b = -0.22117302034568848, new m = 3.264493765955568 and error = 1.1078123374179356 at iteration 138.
# 3.27235787286
# Gradient descent partial with new b = -0.22415743303068186, new m = 3.264671421946677 and error = 1.1073481739357975 at iteration 139.
# 3.27274085873
# Gradient descent partial with new b = -0.22714161864875163, new m = 3.264849064420956 and error = 1.1068841430186636 at iteration 140.
# 3.27312650073
# Gradient descent partial with new b = -0.23012557721717403, new m = 3.265026693379433 and error = 1.1064202446416522 at iteration 141.
# 3.27351479731
# Gradient descent partial with new b = -0.23310930875322397, new m = 3.2652043088231366 and error = 1.105956478779879 at iteration 142.
# 3.2739057469
# Gradient descent partial with new b = -0.23609281327417506, new m = 3.2653819107530953 and error = 1.10549284540847 at iteration 143.
# 3.27429934792
# Gradient descent partial with new b = -0.23907609079729955, new m = 3.2655594991703367 and error = 1.105029344502559 at iteration 144.
# 3.27469559882
# Gradient descent partial with new b = -0.24205914133986844, new m = 3.2657370740758895 and error = 1.1045659760372728 at iteration 145.
# 3.27509449799
# Gradient descent partial with new b = -0.24504196491915137, new m = 3.2659146354707813 and error = 1.10410273998775 at iteration 146.
# 3.27549604386
# Gradient descent partial with new b = -0.24802456155241664, new m = 3.2660921833560406 and error = 1.1036396363291334 at iteration 147.
# 3.27590023482
# Gradient descent partial with new b = -0.25100693125693135, new m = 3.266269717732695 and error = 1.1031766650365662 at iteration 148.
# 3.27630706929
# Gradient descent partial with new b = -0.2539890740499612, new m = 3.2664472386017716 and error = 1.1027138260851965 at iteration 149.
# 3.27671654566
# Gradient descent partial with new b = -0.25697098994877055, new m = 3.266624745964299 and error = 1.1022511194501814 at iteration 150.
# 3.27712866232
# Gradient descent partial with new b = -0.2599526789706225, new m = 3.266802239821305 and error = 1.101788545106677 at iteration 151.
# 3.27754341765
# Gradient descent partial with new b = -0.26293414113277885, new m = 3.2669797201738158 and error = 1.1013261030298396 at iteration 152.
# 3.27796081004
# Gradient descent partial with new b = -0.2659153764525, new m = 3.2671571870228604 and error = 1.1008637931948464 at iteration 153.
# 3.27838083785
# Gradient descent partial with new b = -0.2688963849470452, new m = 3.2673346403694654 and error = 1.100401615576854 at iteration 154.
# 3.27880349946
# Gradient descent partial with new b = -0.2718771666336722, new m = 3.2675120802146584 and error = 1.09993957015105 at iteration 155.
# 3.27922879323
# Gradient descent partial with new b = -0.2748577215296375, new m = 3.2676895065594667 and error = 1.0994776568926017 at iteration 156.
# 3.27965671752
# Gradient descent partial with new b = -0.2778380496521964, new m = 3.2678669194049172 and error = 1.0990158757766966 at iteration 157.
# 3.28008727068
# Gradient descent partial with new b = -0.2808181510186027, new m = 3.268044318752037 and error = 1.0985542267785204 at iteration 158.
# 3.28052045106
# Gradient descent partial with new b = -0.283798025646109, new m = 3.2682217046018534 and error = 1.0980927098732656 at iteration 159.
# 3.28095625699
# Gradient descent partial with new b = -0.2867776735519666, new m = 3.268399076955393 and error = 1.0976313250361203 at iteration 160.
# 3.28139468682
# Gradient descent partial with new b = -0.2897570947534254, new m = 3.268576435813683 and error = 1.0971700722422912 at iteration 161.
# 3.28183573888
# Gradient descent partial with new b = -0.29273628926773415, new m = 3.26875378117775 and error = 1.0967089514669761 at iteration 162.
# 3.2822794115
# Gradient descent partial with new b = -0.2957152571121401, new m = 3.2689311130486205 and error = 1.0962479626853867 at iteration 163.
# 3.28272570299
# Gradient descent partial with new b = -0.29869399830388926, new m = 3.269108431427321 and error = 1.0957871058727322 at iteration 164.
# 3.28317461167
# Gradient descent partial with new b = -0.3016725128602264, new m = 3.269285736314879 and error = 1.0953263810042262 at iteration 165.
# 3.28362613585
# Gradient descent partial with new b = -0.30465080079839485, new m = 3.26946302771232 and error = 1.0948657880550938 at iteration 166.
# 3.28408027383
# Gradient descent partial with new b = -0.3076288621356367, new m = 3.2696403056206704 and error = 1.0944053270005483 at iteration 167.
# 3.28453702392
# Gradient descent partial with new b = -0.3106066968891928, new m = 3.2698175700409573 and error = 1.0939449978158255 at iteration 168.
# 3.28499638441
# Gradient descent partial with new b = -0.3135843050763025, new m = 3.269994820974206 and error = 1.0934848004761577 at iteration 169.
# 3.28545835359
# Gradient descent partial with new b = -0.31656168671420404, new m = 3.2701720584214433 and error = 1.0930247349567803 at iteration 170.
# 3.28592292974
# Gradient descent partial with new b = -0.3195388418201342, new m = 3.270349282383695 and error = 1.0925648012329303 at iteration 171.
# 3.28639011115
# Gradient descent partial with new b = -0.3225157704113285, new m = 3.2705264928619875 and error = 1.092104999279854 at iteration 172.
# 3.28685989609
# Gradient descent partial with new b = -0.3254924725050212, new m = 3.270703689857346 and error = 1.0916453290728012 at iteration 173.
# 3.28733228282
# Gradient descent partial with new b = -0.3284689481184452, new m = 3.270880873370797 and error = 1.0911857905870188 at iteration 174.
# 3.28780726961
# Gradient descent partial with new b = -0.331445197268832, new m = 3.271058043403366 and error = 1.090726383797772 at iteration 175.
# 3.28828485472
# Gradient descent partial with new b = -0.33442121997341195, new m = 3.2712351999560783 and error = 1.0902671086803153 at iteration 176.
# 3.28876503641
# Gradient descent partial with new b = -0.33739701624941404, new m = 3.27141234302996 and error = 1.08980796520992 at iteration 177.
# 3.28924781292
# Gradient descent partial with new b = -0.3403725861140659, new m = 3.2715894726260366 and error = 1.0893489533618472 at iteration 178.
# 3.28973318249
# Gradient descent partial with new b = -0.34334792958459387, new m = 3.2717665887453333 and error = 1.0888900731113742 at iteration 179.
# 3.29022114337
# Gradient descent partial with new b = -0.346323046678223, new m = 3.2719436913888758 and error = 1.0884313244337778 at iteration 180.
# 3.29071169379
# Gradient descent partial with new b = -0.349297937412177, new m = 3.2721207805576893 and error = 1.0879727073043426 at iteration 181.
# 3.29120483198
# Gradient descent partial with new b = -0.3522726018036783, new m = 3.272297856252799 and error = 1.087514221698349 at iteration 182.
# 3.29170055615
# Gradient descent partial with new b = -0.355247039869948, new m = 3.2724749184752295 and error = 1.087055867591086 at iteration 183.
# 3.29219886454
# Gradient descent partial with new b = -0.3582212516282059, new m = 3.2726519672260066 and error = 1.0865976449578523 at iteration 184.
# 3.29269975536
# Gradient descent partial with new b = -0.3611952370956705, new m = 3.272829002506155 and error = 1.0861395537739456 at iteration 185.
# 3.29320322681
# Gradient descent partial with new b = -0.3641689962895589, new m = 3.2730060243166994 and error = 1.0856815940146636 at iteration 186.
# 3.2937092771
# Gradient descent partial with new b = -0.36714252922708707, new m = 3.273183032658665 and error = 1.0852237656553145 at iteration 187.
# 3.29421790443
# Gradient descent partial with new b = -0.3701158359254695, new m = 3.2733600275330765 and error = 1.0847660686712102 at iteration 188.
# 3.29472910699
# Gradient descent partial with new b = -0.37308891640191943, new m = 3.2735370089409583 and error = 1.084308503037663 at iteration 189.
# 3.29524288298
# Gradient descent partial with new b = -0.3760617706736488, new m = 3.273713976883335 and error = 1.0838510687299903 at iteration 190.
# 3.29575923057
# Gradient descent partial with new b = -0.3790343987578683, new m = 3.2738909313612314 and error = 1.0833937657235175 at iteration 191.
# 3.29627814795
# Gradient descent partial with new b = -0.3820068006717872, new m = 3.2740678723756718 and error = 1.0829365939935698 at iteration 192.
# 3.2967996333
# Gradient descent partial with new b = -0.3849789764326135, new m = 3.2742447999276805 and error = 1.082479553515481 at iteration 193.
# 3.29732368479
# Gradient descent partial with new b = -0.3879509260575538, new m = 3.2744217140182816 and error = 1.0820226442645808 at iteration 194.
# 3.29785030057
# Gradient descent partial with new b = -0.3909226495638137, new m = 3.2745986146484998 and error = 1.0815658662162109 at iteration 195.
# 3.29837947882
# Gradient descent partial with new b = -0.3938941469685971, new m = 3.274775501819359 and error = 1.0811092193457141 at iteration 196.
# 3.2989112177
# Gradient descent partial with new b = -0.3968654182891069, new m = 3.2749523755318832 and error = 1.0806527036284406 at iteration 197.
# 3.29944551534
# Gradient descent partial with new b = -0.39983646354254443, new m = 3.2751292357870962 and error = 1.0801963190397401 at iteration 198.
# 3.2999823699
# Gradient descent partial with new b = -0.40280728274610994, new m = 3.275306082586022 and error = 1.0797400655549603 at iteration 199.
# 3.30052177953
# Gradient descent partial with new b = -0.40577787591700226, new m = 3.2754829159296848 and error = 1.0792839431494725 at iteration 200.
# 3.30106374235
# Gradient descent partial with new b = -0.4087482430724189, new m = 3.2756597358191075 and error = 1.0788279517986339 at iteration 201.
# 3.30160825651
# Gradient descent partial with new b = -0.41171838422955614, new m = 3.2758365422553144 and error = 1.0783720914778112 at iteration 202.
# 3.30215532014
# Gradient descent partial with new b = -0.4146882994056088, new m = 3.276013335239329 and error = 1.0779163621623828 at iteration 203.
# 3.30270493135
# Gradient descent partial with new b = -0.4176579886177706, new m = 3.276190114772175 and error = 1.0774607638277225 at iteration 204.
# 3.30325708828
# Gradient descent partial with new b = -0.4206274518832338, new m = 3.2763668808548756 and error = 1.0770052964492058 at iteration 205.
# 3.30381178902
# Gradient descent partial with new b = -0.42359668921918936, new m = 3.276543633488454 and error = 1.0765499600022206 at iteration 206.
# 3.3043690317
# Gradient descent partial with new b = -0.426565700642827, new m = 3.276720372673933 and error = 1.076094754462152 at iteration 207.
# 3.30492881442
# Gradient descent partial with new b = -0.4295344861713351, new m = 3.276897098412337 and error = 1.075639679804396 at iteration 208.
# 3.30549113529
# Gradient descent partial with new b = -0.43250304582190074, new m = 3.277073810704688 and error = 1.0751847360043456 at iteration 209.
# 3.30605599239
# Gradient descent partial with new b = -0.4354713796117096, new m = 3.27725050955201 and error = 1.074729923037407 at iteration 210.
# 3.30662338383
# Gradient descent partial with new b = -0.43843948755794626, new m = 3.277427194955325 and error = 1.0742752408789815 at iteration 211.
# 3.30719330769
# Gradient descent partial with new b = -0.4414073696777938, new m = 3.2776038669156566 and error = 1.0738206895044746 at iteration 212.
# 3.30776576206
# Gradient descent partial with new b = -0.4443750259884341, new m = 3.2777805254340273 and error = 1.0733662688893033 at iteration 213.
# 3.30834074501
# Gradient descent partial with new b = -0.4473424565070476, new m = 3.27795717051146 and error = 1.0729119790088868 at iteration 214.
# 3.30891825463
# Gradient descent partial with new b = -0.4503096612508137, new m = 3.2781338021489765 and error = 1.0724578198386394 at iteration 215.
# 3.30949828898
# Gradient descent partial with new b = -0.4532766402369101, new m = 3.2783104203476006 and error = 1.0720037913539924 at iteration 216.
# 3.31008084613
# Gradient descent partial with new b = -0.4562433934825136, new m = 3.278487025108354 and error = 1.0715498935303682 at iteration 217.
# 3.31066592414
# Gradient descent partial with new b = -0.45920992100479935, new m = 3.27866361643226 and error = 1.071096126343212 at iteration 218.
# 3.31125352108
# Gradient descent partial with new b = -0.46217622282094145, new m = 3.27884019432034 and error = 1.070642489767948 at iteration 219.
# 3.31184363498
# Gradient descent partial with new b = -0.4651422989481126, new m = 3.2790167587736168 and error = 1.0701889837800294 at iteration 220.
# 3.31243626392
# Gradient descent partial with new b = -0.46810814940348416, new m = 3.279193309793112 and error = 1.0697356083548935 at iteration 221.
# 3.31303140593
# Gradient descent partial with new b = -0.4710737742042262, new m = 3.2793698473798476 and error = 1.0692823634679904 at iteration 222.
# 3.31362905904
# Gradient descent partial with new b = -0.47403917336750745, new m = 3.2795463715348467 and error = 1.068829249094779 at iteration 223.
# 3.31422922131
# Gradient descent partial with new b = -0.4770043469104954, new m = 3.2797228822591302 and error = 1.0683762652107114 at iteration 224.
# 3.31483189076
# Gradient descent partial with new b = -0.4799692948503563, new m = 3.279899379553721 and error = 1.067923411791257 at iteration 225.
# 3.31543706542
# Gradient descent partial with new b = -0.4829340172042549, new m = 3.2800758634196394 and error = 1.0674706888118732 at iteration 226.
# 3.31604474332
# Gradient descent partial with new b = -0.4858985139893548, new m = 3.2802523338579084 and error = 1.0670180962480402 at iteration 227.
# 3.31665492247
# Gradient descent partial with new b = -0.48886278522281823, new m = 3.280428790869549 and error = 1.0665656340752223 at iteration 228.
# 3.3172676009
# Gradient descent partial with new b = -0.4918268309218061, new m = 3.2806052344555834 and error = 1.0661133022689053 at iteration 229.
# 3.31788277661
# Gradient descent partial with new b = -0.4947906511034781, new m = 3.2807816646170322 and error = 1.0656611008045667 at iteration 230.
# 3.31850044761
# Gradient descent partial with new b = -0.4977542457849925, new m = 3.2809580813549175 and error = 1.0652090296576973 at iteration 231.
# 3.31912061192
# Gradient descent partial with new b = -0.5007176149835063, new m = 3.28113448467026 and error = 1.0647570888037825 at iteration 232.
# 3.31974326752
# Gradient descent partial with new b = -0.5036807587161753, new m = 3.2813108745640815 and error = 1.064305278218323 at iteration 233.
# 3.32036841242
# Gradient descent partial with new b = -0.5066436770001539, new m = 3.281487251037403 and error = 1.0638535978768102 at iteration 234.
# 3.3209960446
# Gradient descent partial with new b = -0.5096063698525951, new m = 3.281663614091246 and error = 1.0634020477547548 at iteration 235.
# 3.32162616206
# Gradient descent partial with new b = -0.5125688372906507, new m = 3.2818399637266302 and error = 1.062950627827661 at iteration 236.
# 3.32225876278
# Gradient descent partial with new b = -0.5155310793314714, new m = 3.2820162999445777 and error = 1.0624993380710368 at iteration 237.
# 3.32289384474
# Gradient descent partial with new b = -0.5184930959922062, new m = 3.282192622746109 and error = 1.0620481784604023 at iteration 238.
# 3.32353140592
# Gradient descent partial with new b = -0.521454887290003, new m = 3.2823689321322456 and error = 1.0615971489712734 at iteration 239.
# 3.32417144428
# Gradient descent partial with new b = -0.5244164532420084, new m = 3.282545228104007 and error = 1.061146249579175 at iteration 240.
# 3.32481395781
# Gradient descent partial with new b = -0.5273777938653677, new m = 3.2827215106624146 and error = 1.0606954802596336 at iteration 241.
# 3.32545894446
# Gradient descent partial with new b = -0.5303389091772248, new m = 3.282897779808488 and error = 1.0602448409881793 at iteration 242.
# 3.32610640219
# Gradient descent partial with new b = -0.5332997991947225, new m = 3.2830740355432493 and error = 1.059794331740354 at iteration 243.
# 3.32675632896
# Gradient descent partial with new b = -0.536260463935002, new m = 3.2832502778677175 and error = 1.0593439524916877 at iteration 244.
# 3.32740872273
# Gradient descent partial with new b = -0.5392209034152036, new m = 3.2834265067829134 and error = 1.05889370321773 at iteration 245.
# 3.32806358145
# Gradient descent partial with new b = -0.5421811176524658, new m = 3.283602722289857 and error = 1.058443583894027 at iteration 246.
# 3.32872090306
# Gradient descent partial with new b = -0.5451411066639261, new m = 3.2837789243895688 and error = 1.0579935944961305 at iteration 247.
# 3.3293806855
# Gradient descent partial with new b = -0.5481008704667207, new m = 3.283955113083069 and error = 1.0575437349995995 at iteration 248.
# 3.33004292671
# Gradient descent partial with new b = -0.5510604090779845, new m = 3.284131288371377 and error = 1.0570940053799915 at iteration 249.
# 3.33070762463
# Gradient descent partial with new b = -0.5540197225148509, new m = 3.2843074502555134 and error = 1.05664440561287 at iteration 250.
# 3.33137477718
# Gradient descent partial with new b = -0.5569788107944522, new m = 3.2844835987364975 and error = 1.0561949356738027 at iteration 251.
# 3.3320443823
# Gradient descent partial with new b = -0.5599376739339194, new m = 3.2846597338153494 and error = 1.055745595538367 at iteration 252.
# 3.33271643791
# Gradient descent partial with new b = -0.5628963119503819, new m = 3.2848358554930885 and error = 1.05529638518213 at iteration 253.
# 3.33339094193
# Gradient descent partial with new b = -0.5658547248609683, new m = 3.2850119637707347 and error = 1.0548473045806792 at iteration 254.
# 3.33406789228
# Gradient descent partial with new b = -0.5688129126828055, new m = 3.2851880586493074 and error = 1.0543983537095978 at iteration 255.
# 3.33474728686
# Gradient descent partial with new b = -0.5717708754330193, new m = 3.2853641401298264 and error = 1.0539495325444754 at iteration 256.
# 3.3354291236
# Gradient descent partial with new b = -0.5747286131287339, new m = 3.2855402082133103 and error = 1.0535008410609006 at iteration 257.
# 3.33611340038
# Gradient descent partial with new b = -0.5776861257870726, new m = 3.2857162629007792 and error = 1.0530522792344705 at iteration 258.
# 3.33680011513
# Gradient descent partial with new b = -0.5806434134251571, new m = 3.285892304193252 and error = 1.0526038470407924 at iteration 259.
# 3.33748926573
# Gradient descent partial with new b = -0.5836004760601081, new m = 3.2860683320917476 and error = 1.0521555444554633 at iteration 260.
# 3.33818085008
# Gradient descent partial with new b = -0.5865573137090446, new m = 3.2862443465972855 and error = 1.0517073714540948 at iteration 261.
# 3.33887486607
# Gradient descent partial with new b = -0.5895139263890846, new m = 3.2864203477108846 and error = 1.0512593280123026 at iteration 262.
# 3.33957131159
# Gradient descent partial with new b = -0.5924703141173446, new m = 3.2865963354335634 and error = 1.0508114141056983 at iteration 263.
# 3.34027018453
# Gradient descent partial with new b = -0.5954264769109401, new m = 3.2867723097663415 and error = 1.050363629709908 at iteration 264.
# 3.34097148277
# Gradient descent partial with new b = -0.5983824147869848, new m = 3.286948270710237 and error = 1.0499159748005538 at iteration 265.
# 3.34167520418
# Gradient descent partial with new b = -0.6013381277625917, new m = 3.287124218266269 and error = 1.0494684493532664 at iteration 266.
# 3.34238134664
# Gradient descent partial with new b = -0.604293615854872, new m = 3.2873001524354555 and error = 1.0490210533436757 at iteration 267.
# 3.34308990802
# Gradient descent partial with new b = -0.6072488790809357, new m = 3.2874760732188157 and error = 1.0485737867474234 at iteration 268.
# 3.3438008862
# Gradient descent partial with new b = -0.6102039174578918, new m = 3.287651980617368 and error = 1.0481266495401491 at iteration 269.
# 3.34451427903
# Gradient descent partial with new b = -0.6131587310028478, new m = 3.2878278746321303 and error = 1.0476796416974972 at iteration 270.
# 3.34523008437
# Gradient descent partial with new b = -0.6161133197329097, new m = 3.2880037552641213 and error = 1.0472327631951206 at iteration 271.
# 3.34594830009
# Gradient descent partial with new b = -0.6190676836651825, new m = 3.288179622514359 and error = 1.0467860140086709 at iteration 272.
# 3.34666892404
# Gradient descent partial with new b = -0.6220218228167698, new m = 3.288355476383862 and error = 1.0463393941138037 at iteration 273.
# 3.34739195407
# Gradient descent partial with new b = -0.6249757372047737, new m = 3.2885313168736476 and error = 1.0458929034861835 at iteration 274.
# 3.34811738803
# Gradient descent partial with new b = -0.6279294268462954, new m = 3.2887071439847344 and error = 1.0454465421014765 at iteration 275.
# 3.34884522376
# Gradient descent partial with new b = -0.6308828917584345, new m = 3.28888295771814 and error = 1.045000309935347 at iteration 276.
# 3.34957545911
# Gradient descent partial with new b = -0.6338361319582894, new m = 3.2890587580748822 and error = 1.044554206963474 at iteration 277.
# 3.35030809191
# Gradient descent partial with new b = -0.636789147462957, new m = 3.289234545055979 and error = 1.0441082331615348 at iteration 278.
# 3.35104312
# Gradient descent partial with new b = -0.6397419382895333, new m = 3.2894103186624477 and error = 1.0436623885052108 at iteration 279.
# 3.35178054122
# Gradient descent partial with new b = -0.6426945044551127, new m = 3.289586078895306 and error = 1.0432166729701846 at iteration 280.
# 3.35252035339
# Gradient descent partial with new b = -0.6456468459767882, new m = 3.2897618257555723 and error = 1.0427710865321558 at iteration 281.
# 3.35326255434
# Gradient descent partial with new b = -0.648598962871652, new m = 3.289937559244263 and error = 1.0423256291668095 at iteration 282.
# 3.3540071419
# Gradient descent partial with new b = -0.6515508551567945, new m = 3.2901132793623957 and error = 1.0418803008498476 at iteration 283.
# 3.35475411387
# Gradient descent partial with new b = -0.6545025228493049, new m = 3.290288986110988 and error = 1.041435101556968 at iteration 284.
# 3.35550346809
# Gradient descent partial with new b = -0.6574539659662713, new m = 3.2904646794910564 and error = 1.0409900312638833 at iteration 285.
# 3.35625520236
# Gradient descent partial with new b = -0.6604051845247803, new m = 3.2906403595036187 and error = 1.0405450899462994 at iteration 286.
# 3.35700931449
# Gradient descent partial with new b = -0.6633561785419172, new m = 3.290816026149692 and error = 1.040100277579936 at iteration 287.
# 3.3577658023
# Gradient descent partial with new b = -0.6663069480347662, new m = 3.290991679430293 and error = 1.0396555941405041 at iteration 288.
# 3.35852466358
# Gradient descent partial with new b = -0.66925749302041, new m = 3.291167319346439 and error = 1.0392110396037313 at iteration 289.
# 3.35928589615
# Gradient descent partial with new b = -0.6722078135159302, new m = 3.291342945899146 and error = 1.0387666139453418 at iteration 290.
# 3.3600494978
# Gradient descent partial with new b = -0.6751579095384067, new m = 3.291518559089431 and error = 1.038322317141068 at iteration 291.
# 3.36081546632
# Gradient descent partial with new b = -0.6781077811049186, new m = 3.2916941589183115 and error = 1.0378781491666442 at iteration 292.
# 3.36158379951
# Gradient descent partial with new b = -0.6810574282325434, new m = 3.291869745386803 and error = 1.0374341099978086 at iteration 293.
# 3.36235449517
# Gradient descent partial with new b = -0.6840068509383574, new m = 3.292045318495923 and error = 1.0369901996103 at iteration 294.
# 3.36312755107
# Gradient descent partial with new b = -0.6869560492394357, new m = 3.292220878246687 and error = 1.036546417979872 at iteration 295.
# 3.363902965
# Gradient descent partial with new b = -0.6899050231528516, new m = 3.292396424640112 and error = 1.0361027650822718 at iteration 296.
# 3.36468073475
# Gradient descent partial with new b = -0.6928537726956778, new m = 3.292571957677214 and error = 1.0356592408932552 at iteration 297.
# 3.3654608581
# Gradient descent partial with new b = -0.6958022978849854, new m = 3.2927474773590095 and error = 1.0352158453885791 at iteration 298.
# 3.36624333282
# Gradient descent partial with new b = -0.698750598737844, new m = 3.2929229836865144 and error = 1.0347725785440132 at iteration 299.
# 3.36702815668
# Gradient descent partial with new b = -0.7016986752713221, new m = 3.2930984766607447 and error = 1.0343294403353136 at iteration 300.
# 3.36781532746
# Gradient descent partial with new b = -0.704646527502487, new m = 3.2932739562827162 and error = 1.0338864307382603 at iteration 301.
# 3.36860484292
# Gradient descent partial with new b = -0.7075941554484045, new m = 3.2934494225534454 and error = 1.0334435497286227 at iteration 302.
# 3.36939670083
# Gradient descent partial with new b = -0.7105415591261393, new m = 3.293624875473948 and error = 1.0330007972821855 at iteration 303.
# 3.37019089896
# Gradient descent partial with new b = -0.7134887385527544, new m = 3.293800315045239 and error = 1.0325581733747264 at iteration 304.
# 3.37098743506
# Gradient descent partial with new b = -0.716435693745312, new m = 3.293975741268335 and error = 1.0321156779820373 at iteration 305.
# 3.37178630689
# Gradient descent partial with new b = -0.7193824247208729, new m = 3.2941511541442505 and error = 1.0316733110799061 at iteration 306.
# 3.37258751221
# Gradient descent partial with new b = -0.7223289314964962, new m = 3.294326553674002 and error = 1.0312310726441247 at iteration 307.
# 3.37339104877
# Gradient descent partial with new b = -0.7252752140892402, new m = 3.294501939858605 and error = 1.030788962650502 at iteration 308.
# 3.37419691431
# Gradient descent partial with new b = -0.7282212725161616, new m = 3.2946773126990743 and error = 1.0303469810748347 at iteration 309.
# 3.37500510659
# Gradient descent partial with new b = -0.7311671067943161, new m = 3.2948526721964253 and error = 1.0299051278929314 at iteration 310.
# 3.37581562336
# Gradient descent partial with new b = -0.7341127169407576, new m = 3.2950280183516734 and error = 1.0294634030806022 at iteration 311.
# 3.37662846234
# Gradient descent partial with new b = -0.7370581029725392, new m = 3.295203351165833 and error = 1.029021806613663 at iteration 312.
# 3.37744362129
# Gradient descent partial with new b = -0.7400032649067123, new m = 3.2953786706399204 and error = 1.0285803384679395 at iteration 313.
# 3.37826109794
# Gradient descent partial with new b = -0.7429482027603275, new m = 3.2955539767749493 and error = 1.028138998619245 at iteration 314.
# 3.37908089002
# Gradient descent partial with new b = -0.7458929165504335, new m = 3.2957292695719356 and error = 1.0276977870434127 at iteration 315.
# 3.37990299526
# Gradient descent partial with new b = -0.7488374062940784, new m = 3.2959045490318934 and error = 1.0272567037162739 at iteration 316.
# 3.38072741141
# Gradient descent partial with new b = -0.7517816720083083, new m = 3.2960798151558377 and error = 1.0268157486136646 at iteration 317.
# 3.38155413618
# Gradient descent partial with new b = -0.7547257137101684, new m = 3.2962550679447835 and error = 1.0263749217114235 at iteration 318.
# 3.38238316729
# Gradient descent partial with new b = -0.7576695314167026, new m = 3.296430307399745 and error = 1.0259342229853918 at iteration 319.
# 3.38321450248
# Gradient descent partial with new b = -0.7606131251449533, new m = 3.296605533521737 and error = 1.0254936524114238 at iteration 320.
# 3.38404813946
# Gradient descent partial with new b = -0.7635564949119618, new m = 3.2967807463117733 and error = 1.0250532099653653 at iteration 321.
# 3.38488407595
# Gradient descent partial with new b = -0.766499640734768, new m = 3.296955945770869 and error = 1.024612895623071 at iteration 322.
# 3.38572230966
# Gradient descent partial with new b = -0.7694425626304106, new m = 3.297131131900038 and error = 1.0241727093604072 at iteration 323.
# 3.38656283831
# ...
# 14.7523868075
# Gradient descent partial with new b = -14.172646898644883, new m = 4.094996508335336 and error = 0.00046791228417320175 at iteration 5915.
# 14.7542659452
# Gradient descent partial with new b = -14.17456982332952, new m = 4.095110976114003 and error = 0.00046178539134700643 at iteration 5916.
# 14.7561449522
# Gradient descent partial with new b = -14.176492601709795, new m = 4.09522543518347 and error = 0.0004556993379551917 at iteration 5917.
# 14.7580238284
# Gradient descent partial with new b = -14.178415233796839, new m = 4.0953398855444 and error = 0.00044965411474737763 at iteration 5918.
# 14.7599025738
# Gradient descent partial with new b = -14.180337719601784, new m = 4.095454327197455 and error = 0.0004436497124746796 at iteration 5919.
# 14.7617811884
# Gradient descent partial with new b = -14.18226005913576, new m = 4.095568760143299 and error = 0.0004376861218897117 at iteration 5920.
# 14.7636596722
# Gradient descent partial with new b = -14.184182252409895, new m = 4.095683184382593 and error = 0.0004317633337469427 at iteration 5921.
# 14.7655380252
# Gradient descent partial with new b = -14.186104299435318, new m = 4.095797599916 and error = 0.0004258813388022862 at iteration 5922.
# 14.7674162474
# Gradient descent partial with new b = -14.188026200223154, new m = 4.095912006744181 and error = 0.00042004012781337295 at iteration 5923.
# 14.7692943389
# Gradient descent partial with new b = -14.189947954784532, new m = 4.096026404867801 and error = 0.00041423969153952145 at iteration 5924.
# 14.7711722996
# Gradient descent partial with new b = -14.191869563130577, new m = 4.09614079428752 and error = 0.0004084800207417099 at iteration 5925.
# 14.7730501295
# Gradient descent partial with new b = -14.193791025272413, new m = 4.096255175004002 and error = 0.00040276110618241883 at iteration 5926.
# 14.7749278286
# Gradient descent partial with new b = -14.195712341221164, new m = 4.096369547017908 and error = 0.0003970829386257904 at iteration 5927.
# 14.776805397
# Gradient descent partial with new b = -14.197633510987952, new m = 4.0964839103299004 and error = 0.0003914455088378073 at iteration 5928.
# 14.7786828346
# Gradient descent partial with new b = -14.199554534583902, new m = 4.096598264940641 and error = 0.0003858488075857499 at iteration 5929.
# 14.7805601414
# Gradient descent partial with new b = -14.201475412020132, new m = 4.096712610850792 and error = 0.0003802928256388404 at iteration 5930.
# 14.7824373175
# Gradient descent partial with new b = -14.203396143307764, new m = 4.0968269480610155 and error = 0.00037477755376765426 at iteration 5931.
# 14.7843143628
# Gradient descent partial with new b = -14.205316728457918, new m = 4.0969412765719735 and error = 0.00036930298274477814 at iteration 5932.
# 14.7861912774
# Gradient descent partial with new b = -14.207237167481711, new m = 4.097055596384328 and error = 0.0003638691033440535 at iteration 5933.
# 14.7880680613
# Gradient descent partial with new b = -14.209157460390264, new m = 4.09716990749874 and error = 0.0003584759063411061 at iteration 5934.
# 14.7899447144
# Gradient descent partial with new b = -14.21107760719469, new m = 4.097284209915873 and error = 0.0003531233825134379 at iteration 5935.
# 14.7918212367
# Gradient descent partial with new b = -14.212997607906109, new m = 4.097398503636387 and error = 0.0003478115226396433 at iteration 5936.
# 14.7936976284
# Gradient descent partial with new b = -14.214917462535634, new m = 4.097512788660945 and error = 0.0003425403175004378 at iteration 5937.
# 14.7955738893
# Gradient descent partial with new b = -14.216837171094381, new m = 4.097627064990207 and error = 0.000337309757877972 at iteration 5938.
# 14.7974500195
# Gradient descent partial with new b = -14.218756733593464, new m = 4.097741332624835 and error = 0.00033211983455598104 at iteration 5939.
# 14.7993260189
# Gradient descent partial with new b = -14.220676150043994, new m = 4.097855591565492 and error = 0.00032697053831997366 at iteration 5940.
# 14.8012018876
# Gradient descent partial with new b = -14.222595420457084, new m = 4.097969841812838 and error = 0.00032186185995701706 at iteration 5941.
# 14.8030776256
# Gradient descent partial with new b = -14.224514544843846, new m = 4.098084083367535 and error = 0.0003167937902557858 at iteration 5942.
# 14.8049532329
# Gradient descent partial with new b = -14.226433523215388, new m = 4.098198316230245 and error = 0.00031176632000665393 at iteration 5943.
# 14.8068287095
# Gradient descent partial with new b = -14.228352355582821, new m = 4.098312540401627 and error = 0.0003067794400015333 at iteration 5944.
# 14.8087040554
# Gradient descent partial with new b = -14.230271041957254, new m = 4.098426755882345 and error = 0.00030183314103401194 at iteration 5945.
# 14.8105792706
# Gradient descent partial with new b = -14.232189582349795, new m = 4.098540962673059 and error = 0.00029692741389941946 at iteration 5946.
# 14.8124543551
# Gradient descent partial with new b = -14.234107976771549, new m = 4.098655160774431 and error = 0.0002920622493946003 at iteration 5947.
# 14.8143293089
# Gradient descent partial with new b = -14.236026225233624, new m = 4.098769350187121 and error = 0.0002872376383179403 at iteration 5948.
# 14.816204132
# Gradient descent partial with new b = -14.237944327747124, new m = 4.09888353091179 and error = 0.0002824535714696754 at iteration 5949.
# 14.8180788244
# Gradient descent partial with new b = -14.239862284323154, new m = 4.0989977029491 and error = 0.0002777100396514498 at iteration 5950.
# 14.8199533861
# Gradient descent partial with new b = -14.241780094972817, new m = 4.099111866299711 and error = 0.0002730070336667538 at iteration 5951.
# 14.8218278171
# Gradient descent partial with new b = -14.243697759707217, new m = 4.099226020964284 and error = 0.00026834454432053185 at iteration 5952.
# 14.8237021175
# Gradient descent partial with new b = -14.245615278537455, new m = 4.099340166943481 and error = 0.0002637225624194426 at iteration 5953.
# 14.8255762872
# Gradient descent partial with new b = -14.247532651474632, new m = 4.099454304237962 and error = 0.0002591410787717922 at iteration 5954.
# 14.8274503262
# Gradient descent partial with new b = -14.249449878529848, new m = 4.099568432848388 and error = 0.0002546000841874507 at iteration 5955.
# 14.8293242346
# Gradient descent partial with new b = -14.251366959714202, new m = 4.099682552775419 and error = 0.0002500995694779569 at iteration 5956.
# 14.8311980123
# Gradient descent partial with new b = -14.253283895038795, new m = 4.099796664019717 and error = 0.0002456395254564963 at iteration 5957.
# 14.8330716593
# Gradient descent partial with new b = -14.25520068451472, new m = 4.099910766581941 and error = 0.00024121994293781928 at iteration 5958.
# 14.8349451757
# Gradient descent partial with new b = -14.257117328153079, new m = 4.100024860462753 and error = 0.00023684081273828343 at iteration 5959.
# 14.8368185614
# Gradient descent partial with new b = -14.259033825964964, new m = 4.100138945662813 and error = 0.00023250212567607221 at iteration 5960.
# 14.8386918165
# Gradient descent partial with new b = -14.260950177961472, new m = 4.100253022182781 and error = 0.00022820387257071502 at iteration 5961.
# 14.8405649409
# Gradient descent partial with new b = -14.262866384153698, new m = 4.100367090023318 and error = 0.00022394604424360472 at iteration 5962.
# 14.8424379347
# Gradient descent partial with new b = -14.264782444552733, new m = 4.100481149185084 and error = 0.00021972863151762106 at iteration 5963.
# 14.8443107978
# Gradient descent partial with new b = -14.26669835916967, new m = 4.10059519966874 and error = 0.0002155516252173274 at iteration 5964.
# 14.8461835304
# Gradient descent partial with new b = -14.268614128015603, new m = 4.100709241474946 and error = 0.00021141501616891116 at iteration 5965.
# 14.8480561323
# Gradient descent partial with new b = -14.27052975110162, new m = 4.100823274604362 and error = 0.00020731879520018368 at iteration 5966.
# 14.8499286035
# Gradient descent partial with new b = -14.272445228438812, new m = 4.100937299057647 and error = 0.0002032629531405245 at iteration 5967.
# 14.8518009442
# Gradient descent partial with new b = -14.27436056003827, new m = 4.1010513148354635 and error = 0.00019924748082103053 at iteration 5968.
# 14.8536731542
# Gradient descent partial with new b = -14.27627574591108, new m = 4.1011653219384705 and error = 0.0001952723690744024 at iteration 5969.
# 14.8555452336
# Gradient descent partial with new b = -14.27819078606833, new m = 4.101279320367327 and error = 0.00019133760873485557 at iteration 5970.
# 14.8574171824
# Gradient descent partial with new b = -14.280105680521109, new m = 4.1013933101226945 and error = 0.0001874431906384098 at iteration 5971.
# 14.8592890006
# Gradient descent partial with new b = -14.2820204292805, new m = 4.101507291205232 and error = 0.00018358910562256336 at iteration 5972.
# 14.8611606881
# Gradient descent partial with new b = -14.28393503235759, new m = 4.1016212636156 and error = 0.0001797753445265438 at iteration 5973.
# 14.8630322451
# Gradient descent partial with new b = -14.28584948976346, new m = 4.101735227354458 and error = 0.00017600189819111291 at iteration 5974.
# 14.8649036715
# Gradient descent partial with new b = -14.287763801509197, new m = 4.101849182422465 and error = 0.00017226875745874134 at iteration 5975.
# 14.8667749673
# Gradient descent partial with new b = -14.289677967605881, new m = 4.101963128820282 and error = 0.000168575913173385 at iteration 5976.
# 14.8686461325
# Gradient descent partial with new b = -14.291591988064594, new m = 4.102077066548568 and error = 0.00016492335618082526 at iteration 5977.
# 14.8705171671
# Gradient descent partial with new b = -14.293505862896417, new m = 4.102190995607982 and error = 0.000161311077328312 at iteration 5978.
# 14.8723880711
# Gradient descent partial with new b = -14.295419592112431, new m = 4.102304915999185 and error = 0.00015773906746473427 at iteration 5979.
# 14.8742588446
# Gradient descent partial with new b = -14.297333175723715, new m = 4.102418827722835 and error = 0.0001542073174406679 at iteration 5980.
# 14.8761294875
# Gradient descent partial with new b = -14.299246613741346, new m = 4.102532730779593 and error = 0.00015071581810827578 at iteration 5981.
# 14.8779999998
# Gradient descent partial with new b = -14.301159906176402, new m = 4.1026466251701175 and error = 0.00014726456032130984 at iteration 5982.
# 14.8798703815
# Gradient descent partial with new b = -14.303073053039958, new m = 4.102760510895068 and error = 0.0001438535349352368 at iteration 5983.
# 14.8817406327
# Gradient descent partial with new b = -14.304986054343091, new m = 4.102874387955104 and error = 0.00014048273280707908 at iteration 5984.
# 14.8836107533
# Gradient descent partial with new b = -14.306898910096876, new m = 4.102988256350884 and error = 0.0001371521447953877 at iteration 5985.
# 14.8854807433
# Gradient descent partial with new b = -14.308811620312389, new m = 4.103102116083069 and error = 0.00013386176176054785 at iteration 5986.
# 14.8873506029
# Gradient descent partial with new b = -14.3107241850007, new m = 4.103215967152316 and error = 0.0001306115745643805 at iteration 5987.
# 14.8892203318
# Gradient descent partial with new b = -14.312636604172882, new m = 4.103329809559286 and error = 0.00012740157407044583 at iteration 5988.
# 14.8910899302
# Gradient descent partial with new b = -14.314548877840007, new m = 4.103443643304637 and error = 0.000124231751143848 at iteration 5989.
# 14.8929593981
# Gradient descent partial with new b = -14.316461006013146, new m = 4.1035574683890275 and error = 0.00012110209665132511 at iteration 5990.
# 14.8948287354
# Gradient descent partial with new b = -14.318372988703368, new m = 4.103671284813117 and error = 0.00011801260146126223 at iteration 5991.
# 14.8966979422
# Gradient descent partial with new b = -14.320284825921743, new m = 4.103785092577565 and error = 0.00011496325644364756 at iteration 5992.
# 14.8985670185
# Gradient descent partial with new b = -14.322196517679338, new m = 4.103898891683031 and error = 0.00011195405247007332 at iteration 5993.
# 14.9004359642
# Gradient descent partial with new b = -14.32410806398722, new m = 4.104012682130171 and error = 0.00010898498041379061 at iteration 5994.
# 14.9023047794
# Gradient descent partial with new b = -14.326019464856456, new m = 4.104126463919646 and error = 0.00010605603114958614 at iteration 5995.
# 14.9041734641
# Gradient descent partial with new b = -14.327930720298113, new m = 4.104240237052114 and error = 0.00010316719555401173 at iteration 5996.
# 14.9060420183
# Gradient descent partial with new b = -14.329841830323254, new m = 4.104354001528234 and error = 0.00010031846450512707 at iteration 5997.
# 14.907910442
# Gradient descent partial with new b = -14.331752794942943, new m = 4.104467757348665 and error = 9.750982888258375e-05 at iteration 5998.
# 14.9097787352
# Gradient descent partial with new b = -14.333663614168245, new m = 4.104581504514065 and error = 9.474127956772794e-05 at iteration 5999.
# 14.9116468978
# Gradient descent partial with new b = -14.33557428801022, new m = 4.104695243025092 and error = 9.201280744347032e-05 at iteration 6000.
# 14.91351493
# Gradient descent partial with new b = -14.337484816479929, new m = 4.104808972882405 and error = 8.932440339441209e-05 at iteration 6001.
# 14.9153828316
# Gradient descent partial with new b = -14.339395199588434, new m = 4.104922694086663 and error = 8.667605830668237e-05 at iteration 6002.
# 14.9172506028
# Gradient descent partial with new b = -14.341305437346795, new m = 4.105036406638524 and error = 8.406776306807525e-05 at iteration 6003.
# 14.9191182435
# Gradient descent partial with new b = -14.34321552976607, new m = 4.105150110538645 and error = 8.149950856795221e-05 at iteration 6004.
# 14.9209857537
# Gradient descent partial with new b = -14.345125476857318, new m = 4.105263805787686 and error = 7.897128569738406e-05 at iteration 6005.
# 14.9228531334
# Gradient descent partial with new b = -14.347035278631594, new m = 4.105377492386305 and error = 7.648308534897311e-05 at iteration 6006.
# 14.9247203826
# Gradient descent partial with new b = -14.348944935099958, new m = 4.105491170335159 and error = 7.403489841698233e-05 at iteration 6007.
# 14.9265875014
# Gradient descent partial with new b = -14.350854446273463, new m = 4.105604839634907 and error = 7.162671579723263e-05 at iteration 6008.
# 14.9284544897
# Gradient descent partial with new b = -14.352763812163163, new m = 4.105718500286207 and error = 6.92585283872476e-05 at iteration 6009.
# 14.9303213475
# Gradient descent partial with new b = -14.354673032780113, new m = 4.105832152289716 and error = 6.693032708605502e-05 at iteration 6010.
# 14.9321880749
# Gradient descent partial with new b = -14.356582108135365, new m = 4.105945795646094 and error = 6.46421027944461e-05 at iteration 6011.
# 14.9340546718
# Gradient descent partial with new b = -14.358491038239972, new m = 4.106059430355998 and error = 6.239384641469615e-05 at iteration 6012.
# 14.9359211383
# Gradient descent partial with new b = -14.360399823104986, new m = 4.106173056420086 and error = 6.0185548850736344e-05 at iteration 6013.
# 14.9377874743
# Gradient descent partial with new b = -14.362308462741456, new m = 4.106286673839014 and error = 5.801720100808072e-05 at iteration 6014.
# 14.9396536798
# Gradient descent partial with new b = -14.364216957160433, new m = 4.106400282613442 and error = 5.58887937939258e-05 at iteration 6015.
# 14.941519755
# Gradient descent partial with new b = -14.366125306372965, new m = 4.106513882744027 and error = 5.3800318117029714e-05 at iteration 6016.
# 14.9433856996
# Gradient descent partial with new b = -14.368033510390099, new m = 4.106627474231426 and error = 5.175176488780071e-05 at iteration 6017.
# 14.9452515139
# Gradient descent partial with new b = -14.369941569222883, new m = 4.106741057076298 and error = 4.974312501821087e-05 at iteration 6018.
# Gradient descent finished with b = -14.369941569222883, m = 4.106741057076298 and error = 4.974312501821087e-05
