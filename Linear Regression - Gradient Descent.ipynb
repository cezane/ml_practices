# %%
def compute_err_for_points(b, m, points):
    total_error = 0
    for i in range(0, len(points)):
        # [x, y] from dataset (csv file)
        x = points[i, 0]
        y = points[i, 1]
        total_error += (y - (m*x + b))**2
        return total_error / float(len(points))

# %%
def step_gradient(current_b, current_m, points, learning_rate):
    #gradient descent
    gradient_b = 0
    gradient_m = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        gradient_b += -(2/N) * (y - ((current_m * x) + current_b))
        gradient_m += -(2/N) * x * (y - ((current_m * x) + current_b))
        new_b = current_b - (learning_rate * gradient_b)
        new_m = current_m - (learning_rate * gradient_m)
    
    return [new_b, new_m, (gradient_b**2 + gradient_m**2)**0.5]

# %% [markdown]
# The error (RSS) decreases for each iteration.

# %%
def gradient_descent_runner(points, starting_b, starting_m, learning_rate, num_iterations, acceptable_err):
    start_time = time.time()
    b = starting_b
    m = starting_m
    current_err = compute_err_for_points(b, m, points) #Stop condition based in RSS
    gradient_size = current_err
    i = 0
    errors = []
    while (acceptable_err <= current_err and acceptable_err <= gradient_size and i < num_iterations):
        b, m, gradient_size = step_gradient(b, m, array(points), learning_rate)
#        if (gradient_size <= acceptable_err):
#            break
            
        current_err = compute_err_for_points(b, m, points)
        errors.append(current_err)
        print("Gradient descent partial with new b = {}, new m = {}, gradient size = {} and error = {} at iteration {}." \
                                    .format(b, m, gradient_size, current_err, i+1))
        i += 1
    
    end_time = time.time()
    print("Execution time for gradient descent solution: {}.".format(end_time - start_time))

    plt.xlabel("Iterations")
    plt.ylabel("Errors")
    plt.plot(range(0, i), errors)
    return [b, m]

# %% [markdown]
# Below is the closed solution for linear regression.

# %%
def closed_linear_reg(points):
    start_time = time.time()
    sum_x = sum_y = 0
    for i in range(0, len(points)):
        sum_x += points[i, 0]
        sum_y += points[i, 1]
    
    x_mean = sum_x / float(len(points))
    y_mean = sum_y / float(len(points))
    
    a = b = 0
    for i in range(0, len(points)):
        a += (points[i, 0] - x_mean) * (points[i, 1] - y_mean)
        b += (points[i, 0] - x_mean)**2
        
    m = a / b
    b = y_mean - m * x_mean
    end_time = time.time()
    print("Execution time for closed linear regression: {}.".format(end_time - start_time))
    return [b, m]

# %% [markdown]
# For b ~ -39 and m ~ 5, we set the `learning_rate = 0.00335` and the `num_iterations = 14000`. With this setup, we get b ~ -38.99 and m ~ 5.57.
#
# With a `learning_rate = 0.0008` and `num_iterations = 14000`, we get b ~ -25.78 and m ~ 4.79 with an error of ~ 0.7. By using a tolerance (`acceptable_err = 0.00005`), we get b ~ -14.37 and m ~ 4.11, with only 6018 iterations. The gradient size is also considered as a stop condition (tolerance), but, as it can be seen by code execution, the RSS is a more effiecient stop condition for this case.

# %%
def run():
    points = genfromtxt('income.csv', delimiter=',')
    #hyperparameters: 
    #too short --> too slow to converge
    #too great --> never converge
    learning_rate = 0.0008
    #y = mx + b (slope formula)
    initial_b = 0
    initial_m = 0
    num_iterations = 14000
    acceptable_err = 0.00005
    initial_err = compute_err_for_points(initial_b, initial_m, points)
    print("Starting gradient descent with b = {}, m = {} and error = {}".format(initial_b, initial_m, initial_err))
    [b, m] = gradient_descent_runner(points, initial_b, initial_m, learning_rate, num_iterations, acceptable_err)
    print("Gradient descent finished with b = {}, m = {} and error = {}".format(b, m, compute_err_for_points(b, m, points)))
    
    [b_reg, m_reg] = closed_linear_reg(points)
    print("Closed linear regression finished with b = {}, m = {} and error = {}".format(b_reg, m_reg, compute_err_for_points(b_reg, m_reg, points)))

# %%
from numpy import *
import matplotlib.pyplot as plt
import time

if __name__ == '__main__':
    run()
# Out:
# Starting gradient descent with b = 0, m = 0 and error = 23.689789509379533
# Gradient descent partial with new b = 0.08023275089091605, new m = 1.3986596532450708, gradient size = 1751.1987501115955 and error = 5.285290108351334 at iteration 1.
# Gradient descent partial with new b = 0.12453144225733284, new m = 2.1936653028179314, gradient size = 995.2986022652505 and error = 0.7046141727289403 at iteration 2.
# Gradient descent partial with new b = 0.14840711108849813, new m = 2.6455842130784433, gradient size = 565.6864593863816 and error = 9.933393494608196e-05 at iteration 3.
# Gradient descent partial with new b = 0.16067545474686445, new m = 2.9025097802786615, gradient size = 321.52288832132956 and error = 0.21284659454558857 at iteration 4.
# Gradient descent partial with new b = 0.1663468745350518, new m = 3.0486108813778547, gradient size = 182.76392194239685 and error = 0.5316325327633656 at iteration 5.
# Gradient descent partial with new b = 0.1682690318634387, new m = 3.131724894867604, gradient size = 103.92029643530708 and error = 0.7765610690574505 at iteration 6.
# Gradient descent partial with new b = 0.16806039499476258, new m = 3.17904019326321, gradient size = 59.144697982048825 and error = 0.9362003236703794 at iteration 7.
# Gradient descent partial with new b = 0.16664082030614885, new m = 3.206009287202772, gradient size = 33.75803654820291 and error = 1.0333817905499525 at iteration 8.
# Gradient descent partial with new b = 0.1645331081321841, new m = 3.221414610606949, gradient size = 19.436050580829296 and error = 1.0905524851129473 at iteration 9.
# Gradient descent partial with new b = 0.1620343920185508, new m = 3.2302476595102774, gradient size = 11.474587080337702 and error = 1.1235276578870241 at iteration 10.
# Gradient descent partial with new b = 0.15931354779877407, new m = 3.2353453505226155, gradient size = 7.222950285111905 and error = 1.1422825395152836 at iteration 11.
# Gradient descent partial with new b = 0.15646655603983314, new m = 3.2383200451076553, gradient size = 5.146930206100558 and error = 1.1528046865467234 at iteration 12.
# Gradient descent partial with new b = 0.1535479672863295, new m = 3.240088128851462, gradient size = 4.265464591707674 and error = 1.1585995672602052 at iteration 13.
# Gradient descent partial with new b = 0.15058878533099002, new m = 3.2411704294726165, gradient size = 3.938617396878938 and error = 1.1616924210753505 at iteration 14.
# Gradient descent partial with new b = 0.14760663117087752, new m = 3.2418629593885377, gradient size = 3.826887018011916 and error = 1.163244817774244 at iteration 15.
# Gradient descent partial with new b = 0.14461151969157363, new m = 3.2423339572475167, gradient size = 3.789898530267048 and error = 1.1639202759052947 at iteration 16.
# Gradient descent partial with new b = 0.14160914284544673, new m = 3.242679041480305, gradient size = 3.7776790687780606 and error = 1.164096951469225 at iteration 17.
# Gradient descent partial with new b = 0.13860273564591427, new m = 3.2429525568193664, gradient size = 3.773529285136845 and error = 1.1639900878639098 at iteration 18.
# Gradient descent partial with new b = 0.1355941367052211, new m = 3.2431853900920853, gradient size = 3.771993612224713 and error = 1.1637221106222129 at iteration 19.
# Gradient descent partial with new b = 0.13258439099105143, new m = 3.24339509582625, gradient size = 3.7713031896531537 and error = 1.1633626237912735 at iteration 20.
# Gradient descent partial with new b = 0.1295740924032298, new m = 3.2435916511376095, gradient size = 3.770885915940474 and error = 1.1629511908910286 at iteration 21.
# Gradient descent partial with new b = 0.1265635784771779, new m = 3.2437807265200234, gradient size = 3.770556904985044 and error = 1.1625102971501635 at iteration 22.
# Gradient descent partial with new b = 0.12355304104361788, new m = 3.2439655447989413, gradient size = 3.770256422622392 and error = 1.1620527206779243 at iteration 23.
# Gradient descent partial with new b = 0.12054258912201124, new m = 3.24414793766755, gradient size = 3.7699651711803797 and error = 1.1615857228160524 at iteration 24.
# Gradient descent partial with new b = 0.1175322846660428, new m = 3.2443289461690616, gradient size = 3.7696769165363637 and error = 1.16111342981905 at iteration 25.
# Gradient descent partial with new b = 0.11452216287956522, new m = 3.2445091619807993, gradient size = 3.7693896447707806 and error = 1.1606381863919357 at iteration 26.
# Gradient descent partial with new b = 0.11151224376316551, new m = 3.2446889213829984, gradient size = 3.7691027052924317 and error = 1.1601613248758016 at iteration 27.
# Gradient descent partial with new b = 0.10850253867665575, new m = 3.2448684155009673, gradient size = 3.768815887929064 and error = 1.1596836023440062 at iteration 28.
# Gradient descent partial with new b = 0.1054930540688644, new m = 3.2450477529612165, gradient size = 3.7685291247841564 and error = 1.1592054489809003 at iteration 29.
# Gradient descent partial with new b = 0.10248379359746314, new m = 3.2452269955020676, gradient size = 3.76824239392289 and error = 1.1587271092208176 at iteration 30.
# Gradient descent partial with new b = 0.09947475933377033, new m = 3.245406178212941, gradient size = 3.767955688258157 and error = 1.15824872194855 at iteration 31.
# Gradient descent partial with new b = 0.09646595244750107, new m = 3.245585321037355, gradient size = 3.7676690054993904 and error = 1.1577703660720793 at iteration 32.
# Gradient descent partial with new b = 0.09345737359594485, new m = 3.2457644353106563, gradient size = 3.7673823449054984 and error = 1.1572920864185832 at iteration 33.
# Gradient descent partial with new b = 0.0904490231451546, new m = 3.245943527475735, gradient size = 3.767095706235955 and error = 1.1568139084493938 at iteration 34.
# Gradient descent partial with new b = 0.0874409012956596, new m = 3.2461226011948554, gradient size = 3.7668090894119257 and error = 1.1563358466215314 at iteration 35.
# Gradient descent partial with new b = 0.0844330081539143, new m = 3.2463016585499127, gradient size = 3.766522494406829 and error = 1.1558579091390289 at iteration 36.
# Gradient descent partial with new b = 0.08142534377290633, new m = 3.2464807007245997, gradient size = 3.7662359212109555 and error = 1.155380100652746 at iteration 37.
# Gradient descent partial with new b = 0.07841790817523599, new m = 3.246659728392115, gradient size = 3.76594936982004 and error = 1.154902423794529 at iteration 38.
# Gradient descent partial with new b = 0.07541070136623354, new m = 3.2468387419355187, gradient size = 3.76566284023158 and error = 1.1544248800489574 at iteration 39.
# Gradient descent partial with new b = 0.07240372334141436, new m = 3.24701774157297, gradient size = 3.7653763324436595 and error = 1.1539474702486856 at iteration 40.
# Gradient descent partial with new b = 0.06939697409071612, new m = 3.247196727428907, gradient size = 3.7650898464545186 and error = 1.1534701948559334 at iteration 41.
# Gradient descent partial with new b = 0.066390453600907, new m = 3.247375699574502, gradient size = 3.7648033822624742 and error = 1.152993054122438 at iteration 42.
# Gradient descent partial with new b = 0.06338416185695438, new m = 3.247554658050652, gradient size = 3.76451693986586 and error = 1.152516048180313 at iteration 43.
# Gradient descent partial with new b = 0.06037809884280263, new m = 3.2477336028810484, gradient size = 3.764230519263015 and error = 1.1520391770937286 at iteration 44.
# Gradient descent partial with new b = 0.05737226454181537, new m = 3.247912534079603, gradient size = 3.7639441204522757 and error = 1.1515624408882188 at iteration 45.
# Gradient descent partial with new b = 0.054366658937026684, new m = 3.2480914516546706, gradient size = 3.7636577434319936 and error = 1.1510858395673866 at iteration 46.
# Gradient descent partial with new b = 0.05136128201128393, new m = 3.248270355611446, gradient size = 3.763371388200496 and error = 1.1506093731223717 at iteration 47.
# Gradient descent partial with new b = 0.048356133747328924, new m = 3.2484492459533283, gradient size = 3.7630850547561403 and error = 1.1501330415372226 at iteration 48.
# Gradient descent partial with new b = 0.045351214127844056, new m = 3.248628122682697, gradient size = 3.7627987430972545 and error = 1.14965684479197 at iteration 49.
# Gradient descent partial with new b = 0.04234652313547853, new m = 3.2488069858013513, gradient size = 3.7625124532221914 and error = 1.1491807828643663 at iteration 50.
# Gradient descent partial with new b = 0.03934206075286323, new m = 3.248985835310761, gradient size = 3.7622261851292973 and error = 1.1487048557308612 at iteration 51.
# Gradient descent partial with new b = 0.03633782696261923, new m = 3.2491646712122075, gradient size = 3.761939938816901 and error = 1.1482290633671703 at iteration 52.
# Gradient descent partial with new b = 0.03333382174736259, new m = 3.2493434935068666, gradient size = 3.761653714283347 and error = 1.1477534057485894 at iteration 53.
# Gradient descent partial with new b = 0.03033004508970709, new m = 3.2495223021958535, gradient size = 3.761367511526992 and error = 1.1472778828501966 at iteration 54.
# Gradient descent partial with new b = 0.027326496972265774, new m = 3.2497010972802483, gradient size = 3.761081330546169 and error = 1.1468024946469197 at iteration 55.
# Gradient descent partial with new b = 0.02432317737765186, new m = 3.2498798787611123, gradient size = 3.7607951713392245 and error = 1.1463272411136245 at iteration 56.
# Gradient descent partial with new b = 0.021320086288479204, new m = 3.2500586466394945, gradient size = 3.760509033904499 and error = 1.14585212222513 at iteration 57.
# Gradient descent partial with new b = 0.018317223687362647, new m = 3.2502374009164385, gradient size = 3.760222918240335 and error = 1.1453771379562465 at iteration 58.
# Gradient descent partial with new b = 0.015314589556918105, new m = 3.250416141592984, gradient size = 3.759936824345083 and error = 1.1449022882817619 at iteration 59.
# Gradient descent partial with new b = 0.01231218387976271, new m = 3.2505948686701682, gradient size = 3.7596507522170843 and error = 1.1444275731764657 at iteration 60.
# Gradient descent partial with new b = 0.009310006638514843, new m = 3.2507735821490273, gradient size = 3.7593647018546754 and error = 1.1439529926151408 at iteration 61.
# Gradient descent partial with new b = 0.006308057815794183, new m = 3.250952282030597, gradient size = 3.7590786732562025 and error = 1.1434785465725847 at iteration 62.
# Gradient descent partial with new b = 0.0033063373942216895, new m = 3.251130968315912, gradient size = 3.7587926664200224 and error = 1.1430042350235883 at iteration 63.
# Gradient descent partial with new b = 0.00030484535641964747, new m = 3.251309641006008, gradient size = 3.758506681344458 and error = 1.142530057942948 at iteration 64.
# Gradient descent partial with new b = -0.0026964183149883587, new m = 3.251488300101918, gradient size = 3.758220718027871 and error = 1.1420560153054604 at iteration 65.
# Gradient descent partial with new b = -0.005697453637377422, new m = 3.2516669456046774, gradient size = 3.7579347764686055 and error = 1.141582107085933 at iteration 66.
# Gradient descent partial with new b = -0.008698260628121297, new m = 3.2518455775153203, gradient size = 3.7576488566649946 and error = 1.1411083332591698 at iteration 67.
# Gradient descent partial with new b = -0.01169883930459244, new m = 3.2520241958348812, gradient size = 3.7573629586153934 and error = 1.1406346937999894 at iteration 68.
# Gradient descent partial with new b = -0.014699189684161994, new m = 3.2522028005643935, gradient size = 3.7570770823181405 and error = 1.140161188683198 at iteration 69.
# Gradient descent partial with new b = -0.017699311784199735, new m = 3.252381391704892, gradient size = 3.756791227771575 and error = 1.139687817883628 at iteration 70.
# Gradient descent partial with new b = -0.020699205622074186, new m = 3.2525599692574096, gradient size = 3.75650539497406 and error = 1.1392145813760928 at iteration 71.
# Gradient descent partial with new b = -0.023698871215152493, new m = 3.252738533222981, gradient size = 3.756219583923933 and error = 1.1387414791354227 at iteration 72.
# Gradient descent partial with new b = -0.02669830858080049, new m = 3.2529170836026395, gradient size = 3.755933794619528 and error = 1.1382685111364583 at iteration 73.
# Gradient descent partial with new b = -0.029697517736382725, new m = 3.253095620397419, gradient size = 3.7556480270592134 and error = 1.1377956773540256 at iteration 74.
# Gradient descent partial with new b = -0.032696498699262375, new m = 3.253274143608353, gradient size = 3.7553622812413052 and error = 1.1373229777629745 at iteration 75.
# Gradient descent partial with new b = -0.03569525148680133, new m = 3.253452653236475, gradient size = 3.755076557164172 and error = 1.1368504123381473 at iteration 76.
# Gradient descent partial with new b = -0.03869377611636015, new m = 3.2536311492828185, gradient size = 3.7547908548261546 and error = 1.13637798105439 at iteration 77.
# Gradient descent partial with new b = -0.041692072605298065, new m = 3.253809631748417, gradient size = 3.754505174225594 and error = 1.135905683886561 at iteration 78.
# Gradient descent partial with new b = -0.044690140970973, new m = 3.2539881006343037, gradient size = 3.754219515360838 and error = 1.1354335208095208 at iteration 79.
# Gradient descent partial with new b = -0.04768798123074156, new m = 3.2541665559415116, gradient size = 3.7539338782302414 and error = 1.1349614917981214 at iteration 80.
# Gradient descent partial with new b = -0.05068559340195901, new m = 3.254344997671074, gradient size = 3.7536482628321317 and error = 1.134489596827239 at iteration 81.
# Gradient descent partial with new b = -0.0536829775019793, new m = 3.2545234258240234, gradient size = 3.7533626691648734 and error = 1.1340178358717372 at iteration 82.
# Gradient descent partial with new b = -0.05668013354815507, new m = 3.2547018404013937, gradient size = 3.75307709722681 and error = 1.1335462089064943 at iteration 83.
# Gradient descent partial with new b = -0.05967706155783764, new m = 3.2548802414042175, gradient size = 3.752791547016289 and error = 1.1330747159063874 at iteration 84.
# Gradient descent partial with new b = -0.06267376154837702, new m = 3.255058628833527, gradient size = 3.752506018531642 and error = 1.1326033568462999 at iteration 85.
# Gradient descent partial with new b = -0.06567023353712184, new m = 3.2552370026903557, gradient size = 3.7522205117712337 and error = 1.1321321317011224 at iteration 86.
# Gradient descent partial with new b = -0.06866647754141948, new m = 3.255415362975736, gradient size = 3.7519350267333955 and error = 1.131661040445738 at iteration 87.
# Gradient descent partial with new b = -0.07166249357861598, new m = 3.2555937096907, gradient size = 3.7516495634164917 and error = 1.1311900830550505 at iteration 88.
# Gradient descent partial with new b = -0.07465828166605606, new m = 3.255772042836281, gradient size = 3.7513641218188685 and error = 1.1307192595039568 at iteration 89.
# Gradient descent partial with new b = -0.0776538418210831, new m = 3.255950362413511, gradient size = 3.7510787019388587 and error = 1.1302485697673579 at iteration 90.
# Gradient descent partial with new b = -0.08064917406103919, new m = 3.2561286684234227, gradient size = 3.750793303774821 and error = 1.1297780138201667 at iteration 91.
# Gradient descent partial with new b = -0.08364427840326509, new m = 3.2563069608670476, gradient size = 3.7505079273250983 and error = 1.1293075916372914 at iteration 92.
# Gradient descent partial with new b = -0.08663915486510022, new m = 3.2564852397454183, gradient size = 3.7502225725880445 and error = 1.128837303193648 at iteration 93.
# Gradient descent partial with new b = -0.08963380346388271, new m = 3.256663505059567, gradient size = 3.7499372395619996 and error = 1.1283671484641637 at iteration 94.
# Gradient descent partial with new b = -0.09262822421694936, new m = 3.256841756810526, gradient size = 3.749651928245311 and error = 1.1278971274237568 at iteration 95.
# Gradient descent partial with new b = -0.09562241714163563, new m = 3.2570199949993266, gradient size = 3.7493666386363365 and error = 1.1274272400473597 at iteration 96.
# Gradient descent partial with new b = -0.09861638225527572, new m = 3.257198219627001, gradient size = 3.7490813707334256 and error = 1.1269574863099014 at iteration 97.
# Gradient descent partial with new b = -0.10161011957520244, new m = 3.2573764306945807, gradient size = 3.7487961245349135 and error = 1.1264878661863196 at iteration 98.
# Gradient descent partial with new b = -0.10460362911874732, new m = 3.257554628203098, gradient size = 3.7485109000391583 and error = 1.1260183796515617 at iteration 99.
# Gradient descent partial with new b = -0.10759691090324057, new m = 3.257732812153584, gradient size = 3.7482256972445027 and error = 1.125549026680568 at iteration 100.
# Gradient descent partial with new b = -0.11058996494601107, new m = 3.2579109825470702, gradient size = 3.7479405161493076 and error = 1.125079807248292 at iteration 101.
# Gradient descent partial with new b = -0.11358279126438639, new m = 3.2580891393845883, gradient size = 3.747655356751907 and error = 1.1246107213296814 at iteration 102.
# Gradient descent partial with new b = -0.11657538987569277, new m = 3.2582672826671697, gradient size = 3.747370219050668 and error = 1.1241417688996997 at iteration 103.
# Gradient descent partial with new b = -0.11956776079725515, new m = 3.258445412395846, gradient size = 3.747085103043912 and error = 1.1236729499333087 at iteration 104.
# Gradient descent partial with new b = -0.12255990404639713, new m = 3.258623528571648, gradient size = 3.7468000087300184 and error = 1.1232042644054714 at iteration 105.
# Gradient descent partial with new b = -0.12555181964044101, new m = 3.258801631195607, gradient size = 3.7465149361073222 and error = 1.122735712291163 at iteration 106.
# Gradient descent partial with new b = -0.1285435075967078, new m = 3.2589797202687545, gradient size = 3.746229885174171 and error = 1.122267293565357 at iteration 107.
# Gradient descent partial with new b = -0.13153496793251712, new m = 3.2591577957921207, gradient size = 3.7459448559289146 and error = 1.1217990082030342 at iteration 108.
# Gradient descent partial with new b = -0.13452620066518733, new m = 3.2593358577667373, gradient size = 3.7456598483699164 and error = 1.1213308561791735 at iteration 109.
# Gradient descent partial with new b = -0.13751720581203544, new m = 3.2595139061936345, gradient size = 3.7453748624955083 and error = 1.1208628374687601 at iteration 110.
# Gradient descent partial with new b = -0.14050798339037718, new m = 3.2596919410738434, gradient size = 3.745089898304054 and error = 1.1203949520467946 at iteration 111.
# Gradient descent partial with new b = -0.1434985334175269, new m = 3.259869962408395, gradient size = 3.74480495579389 and error = 1.1199271998882654 at iteration 112.
# Gradient descent partial with new b = -0.14648885591079772, new m = 3.260047970198319, gradient size = 3.7445200349633825 and error = 1.1194595809681749 at iteration 113.
# Gradient descent partial with new b = -0.14947895088750135, new m = 3.2602259644446465, gradient size = 3.7442351358108654 and error = 1.1189920952615249 at iteration 114.
# Gradient descent partial with new b = -0.15246881836494824, new m = 3.260403945148408, gradient size = 3.743950258334707 and error = 1.118524742743326 at iteration 115.
# Gradient descent partial with new b = -0.1554584583604475, new m = 3.2605819123106343, gradient size = 3.7436654025332463 and error = 1.1180575233885903 at iteration 116.
# Gradient descent partial with new b = -0.15844787089130696, new m = 3.260759865932355, gradient size = 3.743380568404836 and error = 1.1175904371723342 at iteration 117.
# Gradient descent partial with new b = -0.1614370559748331, new m = 3.2609378060146, gradient size = 3.743095755947829 and error = 1.1171234840695743 at iteration 118.
# Gradient descent partial with new b = -0.16442601362833106, new m = 3.2611157325584004, gradient size = 3.742810965160578 and error = 1.1166566640553435 at iteration 119.
# Gradient descent partial with new b = -0.1674147438691047, new m = 3.261293645564786, gradient size = 3.7425261960414344 and error = 1.1161899771046635 at iteration 120.
# Gradient descent partial with new b = -0.1704032467144566, new m = 3.2614715450347864, gradient size = 3.7422414485887403 and error = 1.1157234231925721 at iteration 121.
# Gradient descent partial with new b = -0.17339152218168796, new m = 3.261649430969432, gradient size = 3.7419567228008614 and error = 1.115257002294102 at iteration 122.
# Gradient descent partial with new b = -0.17637957028809867, new m = 3.261827303369752, gradient size = 3.741672018676141 and error = 1.1147907143842988 at iteration 123.
# Gradient descent partial with new b = -0.17936739105098728, new m = 3.2620051622367767, gradient size = 3.7413873362129255 and error = 1.1143245594382059 at iteration 124.
# Gradient descent partial with new b = -0.18235498448765114, new m = 3.2621830075715352, gradient size = 3.7411026754095826 and error = 1.1138585374308712 at iteration 125.
# Gradient descent partial with new b = -0.18534235061538615, new m = 3.262360839375058, gradient size = 3.7408180362644483 and error = 1.113392648337354 at iteration 126.
# Gradient descent partial with new b = -0.18832948945148695, new m = 3.2625386576483737, gradient size = 3.7405334187758843 and error = 1.1129268921327051 at iteration 127.
# Gradient descent partial with new b = -0.19131640101324687, new m = 3.2627164623925125, gradient size = 3.7402488229422373 and error = 1.1124612687919972 at iteration 128.
# Gradient descent partial with new b = -0.19430308531795792, new m = 3.2628942536085033, gradient size = 3.739964248761871 and error = 1.1119957782902885 at iteration 129.
# Gradient descent partial with new b = -0.19728954238291083, new m = 3.263072031297375, gradient size = 3.7396796962331185 and error = 1.1115304206026464 at iteration 130.
# Gradient descent partial with new b = -0.20027577222539492, new m = 3.263249795460158, gradient size = 3.7393951653543507 and error = 1.1110651957041529 at iteration 131.
# Gradient descent partial with new b = -0.20326177486269825, new m = 3.26342754609788, gradient size = 3.7391106561239047 and error = 1.1106001035698863 at iteration 132.
# Gradient descent partial with new b = -0.2062475503121076, new m = 3.263605283211571, gradient size = 3.7388261685401574 and error = 1.1101351441749256 at iteration 133.
# Gradient descent partial with new b = -0.20923309859090838, new m = 3.2637830068022597, gradient size = 3.738541702601434 and error = 1.1096703174943598 at iteration 134.
# Gradient descent partial with new b = -0.21221841971638472, new m = 3.263960716870975, gradient size = 3.7382572583060996 and error = 1.1092056235032814 at iteration 135.
# Gradient descent partial with new b = -0.21520351370581942, new m = 3.264138413418746, gradient size = 3.7379728356525135 and error = 1.1087410621767866 at iteration 136.
# Gradient descent partial with new b = -0.21818838057649395, new m = 3.2643160964466005, gradient size = 3.737688434639025 and error = 1.108276633489968 at iteration 137.
# Gradient descent partial with new b = -0.22117302034568848, new m = 3.264493765955568, gradient size = 3.737404055263979 and error = 1.1078123374179356 at iteration 138.
# Gradient descent partial with new b = -0.22415743303068186, new m = 3.264671421946677, gradient size = 3.737119697525736 and error = 1.1073481739357975 at iteration 139.
# Gradient descent partial with new b = -0.22714161864875163, new m = 3.264849064420956, gradient size = 3.736835361422653 and error = 1.1068841430186636 at iteration 140.
# Gradient descent partial with new b = -0.23012557721717403, new m = 3.265026693379433, gradient size = 3.736551046953084 and error = 1.1064202446416522 at iteration 141.
# Gradient descent partial with new b = -0.23310930875322397, new m = 3.2652043088231366, gradient size = 3.736266754115371 and error = 1.105956478779879 at iteration 142.
# Gradient descent partial with new b = -0.23609281327417506, new m = 3.2653819107530953, gradient size = 3.7359824829078883 and error = 1.10549284540847 at iteration 143.
# Gradient descent partial with new b = -0.23907609079729955, new m = 3.2655594991703367, gradient size = 3.735698233328973 and error = 1.105029344502559 at iteration 144.
# Gradient descent partial with new b = -0.24205914133986844, new m = 3.2657370740758895, gradient size = 3.7354140053769864 and error = 1.1045659760372728 at iteration 145.
# Gradient descent partial with new b = -0.24504196491915137, new m = 3.2659146354707813, gradient size = 3.735129799050283 and error = 1.10410273998775 at iteration 146.
# Gradient descent partial with new b = -0.24802456155241664, new m = 3.2660921833560406, gradient size = 3.7348456143472095 and error = 1.1036396363291334 at iteration 147.
# Gradient descent partial with new b = -0.25100693125693135, new m = 3.266269717732695, gradient size = 3.734561451266133 and error = 1.1031766650365662 at iteration 148.
# Gradient descent partial with new b = -0.2539890740499612, new m = 3.2664472386017716, gradient size = 3.734277309805405 and error = 1.1027138260851965 at iteration 149.
# Gradient descent partial with new b = -0.25697098994877055, new m = 3.266624745964299, gradient size = 3.733993189963378 and error = 1.1022511194501814 at iteration 150.
# Gradient descent partial with new b = -0.2599526789706225, new m = 3.266802239821305, gradient size = 3.733709091738409 and error = 1.101788545106677 at iteration 151.
# Gradient descent partial with new b = -0.26293414113277885, new m = 3.2669797201738158, gradient size = 3.7334250151288435 and error = 1.1013261030298396 at iteration 152.
# Gradient descent partial with new b = -0.2659153764525, new m = 3.2671571870228604, gradient size = 3.7331409601330514 and error = 1.1008637931948464 at iteration 153.
# Gradient descent partial with new b = -0.2688963849470452, new m = 3.2673346403694654, gradient size = 3.732856926749388 and error = 1.100401615576854 at iteration 154.
# Gradient descent partial with new b = -0.2718771666336722, new m = 3.2675120802146584, gradient size = 3.732572914976198 and error = 1.09993957015105 at iteration 155.
# Gradient descent partial with new b = -0.2748577215296375, new m = 3.2676895065594667, gradient size = 3.732288924811841 and error = 1.0994776568926017 at iteration 156.
# Gradient descent partial with new b = -0.2778380496521964, new m = 3.2678669194049172, gradient size = 3.7320049562546727 and error = 1.0990158757766966 at iteration 157.
# Gradient descent partial with new b = -0.2808181510186027, new m = 3.268044318752037, gradient size = 3.731721009303058 and error = 1.0985542267785204 at iteration 158.
# Gradient descent partial with new b = -0.283798025646109, new m = 3.2682217046018534, gradient size = 3.731437083955337 and error = 1.0980927098732656 at iteration 159.
# Gradient descent partial with new b = -0.2867776735519666, new m = 3.268399076955393, gradient size = 3.731153180209879 and error = 1.0976313250361203 at iteration 160.
# Gradient descent partial with new b = -0.2897570947534254, new m = 3.268576435813683, gradient size = 3.7308692980650386 and error = 1.0971700722422912 at iteration 161.
# Gradient descent partial with new b = -0.29273628926773415, new m = 3.26875378117775, gradient size = 3.7305854375191694 and error = 1.0967089514669761 at iteration 162.
# Gradient descent partial with new b = -0.2957152571121401, new m = 3.2689311130486205, gradient size = 3.7303015985706276 and error = 1.0962479626853867 at iteration 163.
# Gradient descent partial with new b = -0.29869399830388926, new m = 3.269108431427321, gradient size = 3.730017781217771 and error = 1.0957871058727322 at iteration 164.
# Gradient descent partial with new b = -0.3016725128602264, new m = 3.269285736314879, gradient size = 3.729733985458955 and error = 1.0953263810042262 at iteration 165.
# Gradient descent partial with new b = -0.30465080079839485, new m = 3.26946302771232, gradient size = 3.729450211292537 and error = 1.0948657880550938 at iteration 166.
# Gradient descent partial with new b = -0.3076288621356367, new m = 3.2696403056206704, gradient size = 3.7291664587168833 and error = 1.0944053270005483 at iteration 167.
# Gradient descent partial with new b = -0.3106066968891928, new m = 3.2698175700409573, gradient size = 3.7288827277303285 and error = 1.0939449978158255 at iteration 168.
# Gradient descent partial with new b = -0.3135843050763025, new m = 3.269994820974206, gradient size = 3.728599018331256 and error = 1.0934848004761577 at iteration 169.
# Gradient descent partial with new b = -0.31656168671420404, new m = 3.2701720584214433, gradient size = 3.728315330518013 and error = 1.0930247349567803 at iteration 170.
# Gradient descent partial with new b = -0.3195388418201342, new m = 3.270349282383695, gradient size = 3.7280316642889533 and error = 1.0925648012329303 at iteration 171.
# Gradient descent partial with new b = -0.3225157704113285, new m = 3.2705264928619875, gradient size = 3.7277480196424317 and error = 1.092104999279854 at iteration 172.
# Gradient descent partial with new b = -0.3254924725050212, new m = 3.270703689857346, gradient size = 3.727464396576818 and error = 1.0916453290728012 at iteration 173.
# Gradient descent partial with new b = -0.3284689481184452, new m = 3.270880873370797, gradient size = 3.72718079509047 and error = 1.0911857905870188 at iteration 174.
# Gradient descent partial with new b = -0.331445197268832, new m = 3.271058043403366, gradient size = 3.7268972151817237 and error = 1.090726383797772 at iteration 175.
# Gradient descent partial with new b = -0.33442121997341195, new m = 3.2712351999560783, gradient size = 3.726613656848968 and error = 1.0902671086803153 at iteration 176.
# Gradient descent partial with new b = -0.33739701624941404, new m = 3.27141234302996, gradient size = 3.7263301200905445 and error = 1.08980796520992 at iteration 177.
# Gradient descent partial with new b = -0.3403725861140659, new m = 3.2715894726260366, gradient size = 3.726046604904816 and error = 1.0893489533618472 at iteration 178.
# Gradient descent partial with new b = -0.34334792958459387, new m = 3.2717665887453333, gradient size = 3.7257631112901324 and error = 1.0888900731113742 at iteration 179.
# Gradient descent partial with new b = -0.346323046678223, new m = 3.2719436913888758, gradient size = 3.7254796392448606 and error = 1.0884313244337778 at iteration 180.
# Gradient descent partial with new b = -0.349297937412177, new m = 3.2721207805576893, gradient size = 3.7251961887673626 and error = 1.0879727073043426 at iteration 181.
# Gradient descent partial with new b = -0.3522726018036783, new m = 3.272297856252799, gradient size = 3.724912759855989 and error = 1.087514221698349 at iteration 182.
# Gradient descent partial with new b = -0.355247039869948, new m = 3.2724749184752295, gradient size = 3.7246293525091065 and error = 1.087055867591086 at iteration 183.
# Gradient descent partial with new b = -0.3582212516282059, new m = 3.2726519672260066, gradient size = 3.7243459667250662 and error = 1.0865976449578523 at iteration 184.
# Gradient descent partial with new b = -0.3611952370956705, new m = 3.272829002506155, gradient size = 3.72406260250224 and error = 1.0861395537739456 at iteration 185.
# Gradient descent partial with new b = -0.3641689962895589, new m = 3.2730060243166994, gradient size = 3.7237792598389796 and error = 1.0856815940146636 at iteration 186.
# Gradient descent partial with new b = -0.36714252922708707, new m = 3.273183032658665, gradient size = 3.723495938733642 and error = 1.0852237656553145 at iteration 187.
# Gradient descent partial with new b = -0.3701158359254695, new m = 3.2733600275330765, gradient size = 3.7232126391845877 and error = 1.0847660686712102 at iteration 188.
# Gradient descent partial with new b = -0.37308891640191943, new m = 3.2735370089409583, gradient size = 3.72292936119018 and error = 1.084308503037663 at iteration 189.
# Gradient descent partial with new b = -0.3760617706736488, new m = 3.273713976883335, gradient size = 3.7226461047487795 and error = 1.0838510687299903 at iteration 190.
# Gradient descent partial with new b = -0.3790343987578683, new m = 3.2738909313612314, gradient size = 3.722362869858738 and error = 1.0833937657235175 at iteration 191.
# Gradient descent partial with new b = -0.3820068006717872, new m = 3.2740678723756718, gradient size = 3.722079656518431 and error = 1.0829365939935698 at iteration 192.
# Gradient descent partial with new b = -0.3849789764326135, new m = 3.2742447999276805, gradient size = 3.721796464726202 and error = 1.082479553515481 at iteration 193.
# Gradient descent partial with new b = -0.3879509260575538, new m = 3.2744217140182816, gradient size = 3.721513294480429 and error = 1.0820226442645808 at iteration 194.
# Gradient descent partial with new b = -0.3909226495638137, new m = 3.2745986146484998, gradient size = 3.721230145779456 and error = 1.0815658662162109 at iteration 195.
# Gradient descent partial with new b = -0.3938941469685971, new m = 3.274775501819359, gradient size = 3.720947018621657 and error = 1.0811092193457141 at iteration 196.
# Gradient descent partial with new b = -0.3968654182891069, new m = 3.2749523755318832, gradient size = 3.720663913005379 and error = 1.0806527036284406 at iteration 197.
# Gradient descent partial with new b = -0.39983646354254443, new m = 3.2751292357870962, gradient size = 3.7203808289289992 and error = 1.0801963190397401 at iteration 198.
# Gradient descent partial with new b = -0.40280728274610994, new m = 3.275306082586022, gradient size = 3.7200977663908668 and error = 1.0797400655549603 at iteration 199.
# Gradient descent partial with new b = -0.40577787591700226, new m = 3.2754829159296848, gradient size = 3.7198147253893494 and error = 1.0792839431494725 at iteration 200.
# Gradient descent partial with new b = -0.4087482430724189, new m = 3.2756597358191075, gradient size = 3.719531705922807 and error = 1.0788279517986339 at iteration 201.
# Gradient descent partial with new b = -0.41171838422955614, new m = 3.2758365422553144, gradient size = 3.7192487079895975 and error = 1.0783720914778112 at iteration 202.
# Gradient descent partial with new b = -0.4146882994056088, new m = 3.276013335239329, gradient size = 3.7189657315880793 and error = 1.0779163621623828 at iteration 203.
# Gradient descent partial with new b = -0.4176579886177706, new m = 3.276190114772175, gradient size = 3.718682776716632 and error = 1.0774607638277225 at iteration 204.
# Gradient descent partial with new b = -0.4206274518832338, new m = 3.2763668808548756, gradient size = 3.7183998433736 and error = 1.0770052964492058 at iteration 205.
# Gradient descent partial with new b = -0.42359668921918936, new m = 3.276543633488454, gradient size = 3.7181169315573497 and error = 1.0765499600022206 at iteration 206.
# Gradient descent partial with new b = -0.426565700642827, new m = 3.276720372673933, gradient size = 3.7178340412662387 and error = 1.076094754462152 at iteration 207.
# Gradient descent partial with new b = -0.4295344861713351, new m = 3.276897098412337, gradient size = 3.7175511724986463 and error = 1.075639679804396 at iteration 208.
# Gradient descent partial with new b = -0.43250304582190074, new m = 3.277073810704688, gradient size = 3.7172683252529155 and error = 1.0751847360043456 at iteration 209.
# Gradient descent partial with new b = -0.4354713796117096, new m = 3.27725050955201, gradient size = 3.716985499527418 and error = 1.074729923037407 at iteration 210.
# Gradient descent partial with new b = -0.43843948755794626, new m = 3.277427194955325, gradient size = 3.7167026953205236 and error = 1.0742752408789815 at iteration 211.
# Gradient descent partial with new b = -0.4414073696777938, new m = 3.2776038669156566, gradient size = 3.716419912630581 and error = 1.0738206895044746 at iteration 212.
# Gradient descent partial with new b = -0.4443750259884341, new m = 3.2777805254340273, gradient size = 3.716137151455956 and error = 1.0733662688893033 at iteration 213.
# Gradient descent partial with new b = -0.4473424565070476, new m = 3.27795717051146, gradient size = 3.7158544117950143 and error = 1.0729119790088868 at iteration 214.
# Gradient descent partial with new b = -0.4503096612508137, new m = 3.2781338021489765, gradient size = 3.7155716936461287 and error = 1.0724578198386394 at iteration 215.
# Gradient descent partial with new b = -0.4532766402369101, new m = 3.2783104203476006, gradient size = 3.7152889970076415 and error = 1.0720037913539924 at iteration 216.
# Gradient descent partial with new b = -0.4562433934825136, new m = 3.278487025108354, gradient size = 3.7150063218779303 and error = 1.0715498935303682 at iteration 217.
# Gradient descent partial with new b = -0.45920992100479935, new m = 3.27866361643226, gradient size = 3.71472366825536 and error = 1.071096126343212 at iteration 218.
# Gradient descent partial with new b = -0.46217622282094145, new m = 3.27884019432034, gradient size = 3.7144410361382927 and error = 1.070642489767948 at iteration 219.
# Gradient descent partial with new b = -0.4651422989481126, new m = 3.2790167587736168, gradient size = 3.7141584255250852 and error = 1.0701889837800294 at iteration 220.
# Gradient descent partial with new b = -0.46810814940348416, new m = 3.279193309793112, gradient size = 3.7138758364141045 and error = 1.0697356083548935 at iteration 221.
# Gradient descent partial with new b = -0.4710737742042262, new m = 3.2793698473798476, gradient size = 3.7135932688037148 and error = 1.0692823634679904 at iteration 222.
# Gradient descent partial with new b = -0.47403917336750745, new m = 3.2795463715348467, gradient size = 3.713310722692287 and error = 1.068829249094779 at iteration 223.
# Gradient descent partial with new b = -0.4770043469104954, new m = 3.2797228822591302, gradient size = 3.713028198078175 and error = 1.0683762652107114 at iteration 224.
# Gradient descent partial with new b = -0.4799692948503563, new m = 3.279899379553721, gradient size = 3.7127456949597466 and error = 1.067923411791257 at iteration 225.
# Gradient descent partial with new b = -0.4829340172042549, new m = 3.2800758634196394, gradient size = 3.7124632133353774 and error = 1.0674706888118732 at iteration 226.
# Gradient descent partial with new b = -0.4858985139893548, new m = 3.2802523338579084, gradient size = 3.7121807532034112 and error = 1.0670180962480402 at iteration 227.
# Gradient descent partial with new b = -0.48886278522281823, new m = 3.280428790869549, gradient size = 3.7118983145622284 and error = 1.0665656340752223 at iteration 228.
# Gradient descent partial with new b = -0.4918268309218061, new m = 3.2806052344555834, gradient size = 3.7116158974101876 and error = 1.0661133022689053 at iteration 229.
# Gradient descent partial with new b = -0.4947906511034781, new m = 3.2807816646170322, gradient size = 3.711333501745665 and error = 1.0656611008045667 at iteration 230.
# Gradient descent partial with new b = -0.4977542457849925, new m = 3.2809580813549175, gradient size = 3.7110511275670053 and error = 1.0652090296576973 at iteration 231.
# Gradient descent partial with new b = -0.5007176149835063, new m = 3.28113448467026, gradient size = 3.710768774872591 and error = 1.0647570888037825 at iteration 232.
# Gradient descent partial with new b = -0.5036807587161753, new m = 3.2813108745640815, gradient size = 3.7104864436607805 and error = 1.064305278218323 at iteration 233.
# Gradient descent partial with new b = -0.5066436770001539, new m = 3.281487251037403, gradient size = 3.710204133929937 and error = 1.0638535978768102 at iteration 234.
# Gradient descent partial with new b = -0.5096063698525951, new m = 3.281663614091246, gradient size = 3.7099218456784238 and error = 1.0634020477547548 at iteration 235.
# Gradient descent partial with new b = -0.5125688372906507, new m = 3.2818399637266302, gradient size = 3.7096395789046186 and error = 1.062950627827661 at iteration 236.
# Gradient descent partial with new b = -0.5155310793314714, new m = 3.2820162999445777, gradient size = 3.7093573336068864 and error = 1.0624993380710368 at iteration 237.
# Gradient descent partial with new b = -0.5184930959922062, new m = 3.282192622746109, gradient size = 3.7090751097835812 and error = 1.0620481784604023 at iteration 238.
# Gradient descent partial with new b = -0.521454887290003, new m = 3.2823689321322456, gradient size = 3.708792907433083 and error = 1.0615971489712734 at iteration 239.
# Gradient descent partial with new b = -0.5244164532420084, new m = 3.282545228104007, gradient size = 3.7085107265537376 and error = 1.061146249579175 at iteration 240.
# Gradient descent partial with new b = -0.5273777938653677, new m = 3.2827215106624146, gradient size = 3.7082285671439372 and error = 1.0606954802596336 at iteration 241.
# Gradient descent partial with new b = -0.5303389091772248, new m = 3.282897779808488, gradient size = 3.7079464292020243 and error = 1.0602448409881793 at iteration 242.
# Gradient descent partial with new b = -0.5332997991947225, new m = 3.2830740355432493, gradient size = 3.707664312726388 and error = 1.059794331740354 at iteration 243.
# Gradient descent partial with new b = -0.536260463935002, new m = 3.2832502778677175, gradient size = 3.7073822177153746 and error = 1.0593439524916877 at iteration 244.
# Gradient descent partial with new b = -0.5392209034152036, new m = 3.2834265067829134, gradient size = 3.707100144167362 and error = 1.05889370321773 at iteration 245.
# Gradient descent partial with new b = -0.5421811176524658, new m = 3.283602722289857, gradient size = 3.7068180920807157 and error = 1.058443583894027 at iteration 246.
# Gradient descent partial with new b = -0.5451411066639261, new m = 3.2837789243895688, gradient size = 3.706536061453801 and error = 1.0579935944961305 at iteration 247.
# Gradient descent partial with new b = -0.5481008704667207, new m = 3.283955113083069, gradient size = 3.7062540522849923 and error = 1.0575437349995995 at iteration 248.
# Gradient descent partial with new b = -0.5510604090779845, new m = 3.284131288371377, gradient size = 3.7059720645726495 and error = 1.0570940053799915 at iteration 249.
# Gradient descent partial with new b = -0.5540197225148509, new m = 3.2843074502555134, gradient size = 3.7056900983151353 and error = 1.05664440561287 at iteration 250.
# Gradient descent partial with new b = -0.5569788107944522, new m = 3.2844835987364975, gradient size = 3.7054081535108296 and error = 1.0561949356738027 at iteration 251.
# Gradient descent partial with new b = -0.5599376739339194, new m = 3.2846597338153494, gradient size = 3.705126230158098 and error = 1.055745595538367 at iteration 252.
# Gradient descent partial with new b = -0.5628963119503819, new m = 3.2848358554930885, gradient size = 3.7048443282552976 and error = 1.05529638518213 at iteration 253.
# Gradient descent partial with new b = -0.5658547248609683, new m = 3.2850119637707347, gradient size = 3.7045624478008037 and error = 1.0548473045806792 at iteration 254.
# Gradient descent partial with new b = -0.5688129126828055, new m = 3.2851880586493074, gradient size = 3.7042805887929937 and error = 1.0543983537095978 at iteration 255.
# Gradient descent partial with new b = -0.5717708754330193, new m = 3.2853641401298264, gradient size = 3.7039987512302206 and error = 1.0539495325444754 at iteration 256.
# Gradient descent partial with new b = -0.5747286131287339, new m = 3.2855402082133103, gradient size = 3.703716935110855 and error = 1.0535008410609006 at iteration 257.
# Gradient descent partial with new b = -0.5776861257870726, new m = 3.2857162629007792, gradient size = 3.7034351404332737 and error = 1.0530522792344705 at iteration 258.
# Gradient descent partial with new b = -0.5806434134251571, new m = 3.285892304193252, gradient size = 3.703153367195837 and error = 1.0526038470407924 at iteration 259.
# Gradient descent partial with new b = -0.5836004760601081, new m = 3.2860683320917476, gradient size = 3.7028716153969166 and error = 1.0521555444554633 at iteration 260.
# Gradient descent partial with new b = -0.5865573137090446, new m = 3.2862443465972855, gradient size = 3.7025898850348904 and error = 1.0517073714540948 at iteration 261.
# Gradient descent partial with new b = -0.5895139263890846, new m = 3.2864203477108846, gradient size = 3.7023081761081187 and error = 1.0512593280123026 at iteration 262.
# Gradient descent partial with new b = -0.5924703141173446, new m = 3.2865963354335634, gradient size = 3.702026488614962 and error = 1.0508114141056983 at iteration 263.
# Gradient descent partial with new b = -0.5954264769109401, new m = 3.2867723097663415, gradient size = 3.7017448225538057 and error = 1.050363629709908 at iteration 264.
# Gradient descent partial with new b = -0.5983824147869848, new m = 3.286948270710237, gradient size = 3.7014631779230056 and error = 1.0499159748005538 at iteration 265.
# Gradient descent partial with new b = -0.6013381277625917, new m = 3.287124218266269, gradient size = 3.7011815547209377 and error = 1.0494684493532664 at iteration 266.
# Gradient descent partial with new b = -0.604293615854872, new m = 3.2873001524354555, gradient size = 3.7008999529459725 and error = 1.0490210533436757 at iteration 267.
# Gradient descent partial with new b = -0.6072488790809357, new m = 3.2874760732188157, gradient size = 3.7006183725964856 and error = 1.0485737867474234 at iteration 268.
# Gradient descent partial with new b = -0.6102039174578918, new m = 3.287651980617368, gradient size = 3.7003368136708383 and error = 1.0481266495401491 at iteration 269.
# Gradient descent partial with new b = -0.6131587310028478, new m = 3.2878278746321303, gradient size = 3.700055276167397 and error = 1.0476796416974972 at iteration 270.
# Gradient descent partial with new b = -0.6161133197329097, new m = 3.2880037552641213, gradient size = 3.6997737600845384 and error = 1.0472327631951206 at iteration 271.
# Gradient descent partial with new b = -0.6190676836651825, new m = 3.288179622514359, gradient size = 3.6994922654206333 and error = 1.0467860140086709 at iteration 272.
# Gradient descent partial with new b = -0.6220218228167698, new m = 3.288355476383862, gradient size = 3.6992107921740502 and error = 1.0463393941138037 at iteration 273.
# Gradient descent partial with new b = -0.6249757372047737, new m = 3.2885313168736476, gradient size = 3.698929340343157 and error = 1.0458929034861835 at iteration 274.
# Gradient descent partial with new b = -0.6279294268462954, new m = 3.2887071439847344, gradient size = 3.6986479099263305 and error = 1.0454465421014765 at iteration 275.
# Gradient descent partial with new b = -0.6308828917584345, new m = 3.28888295771814, gradient size = 3.6983665009219346 and error = 1.045000309935347 at iteration 276.
# Gradient descent partial with new b = -0.6338361319582894, new m = 3.2890587580748822, gradient size = 3.6980851133283448 and error = 1.044554206963474 at iteration 277.
# Gradient descent partial with new b = -0.636789147462957, new m = 3.289234545055979, gradient size = 3.6978037471439307 and error = 1.0441082331615348 at iteration 278.
# Gradient descent partial with new b = -0.6397419382895333, new m = 3.2894103186624477, gradient size = 3.697522402367068 and error = 1.0436623885052108 at iteration 279.
# Gradient descent partial with new b = -0.6426945044551127, new m = 3.289586078895306, gradient size = 3.697241078996115 and error = 1.0432166729701846 at iteration 280.
# Gradient descent partial with new b = -0.6456468459767882, new m = 3.2897618257555723, gradient size = 3.696959777029446 and error = 1.0427710865321558 at iteration 281.
# Gradient descent partial with new b = -0.648598962871652, new m = 3.289937559244263, gradient size = 3.696678496465447 and error = 1.0423256291668095 at iteration 282.
# ...
# Gradient descent partial with new b = -14.199554534583902, new m = 4.096598264940641, gradient size = 2.4055302927541966 and error = 0.0003858488075857499 at iteration 5929.
# Gradient descent partial with new b = -14.201475412020132, new m = 4.096712610850792, gradient size = 2.4053472696870615 and error = 0.0003802928256388404 at iteration 5930.
# Gradient descent partial with new b = -14.203396143307764, new m = 4.0968269480610155, gradient size = 2.40516426054511 and error = 0.00037477755376765426 at iteration 5931.
# Gradient descent partial with new b = -14.205316728457918, new m = 4.0969412765719735, gradient size = 2.4049812653272737 and error = 0.00036930298274477814 at iteration 5932.
# Gradient descent partial with new b = -14.207237167481711, new m = 4.097055596384328, gradient size = 2.404798284032503 and error = 0.0003638691033440535 at iteration 5933.
# Gradient descent partial with new b = -14.209157460390264, new m = 4.09716990749874, gradient size = 2.404615316659731 and error = 0.0003584759063411061 at iteration 5934.
# Gradient descent partial with new b = -14.21107760719469, new m = 4.097284209915873, gradient size = 2.4044323632079054 and error = 0.0003531233825134379 at iteration 5935.
# Gradient descent partial with new b = -14.212997607906109, new m = 4.097398503636387, gradient size = 2.4042494236759655 and error = 0.0003478115226396433 at iteration 5936.
# Gradient descent partial with new b = -14.214917462535634, new m = 4.097512788660945, gradient size = 2.404066498062841 and error = 0.0003425403175004378 at iteration 5937.
# Gradient descent partial with new b = -14.216837171094381, new m = 4.097627064990207, gradient size = 2.403883586367494 and error = 0.000337309757877972 at iteration 5938.
# Gradient descent partial with new b = -14.218756733593464, new m = 4.097741332624835, gradient size = 2.4037006885888443 and error = 0.00033211983455598104 at iteration 5939.
# Gradient descent partial with new b = -14.220676150043994, new m = 4.097855591565492, gradient size = 2.403517804725847 and error = 0.00032697053831997366 at iteration 5940.
# Gradient descent partial with new b = -14.222595420457084, new m = 4.097969841812838, gradient size = 2.4033349347774373 and error = 0.00032186185995701706 at iteration 5941.
# Gradient descent partial with new b = -14.224514544843846, new m = 4.098084083367535, gradient size = 2.4031520787425578 and error = 0.0003167937902557858 at iteration 5942.
# Gradient descent partial with new b = -14.226433523215388, new m = 4.098198316230245, gradient size = 2.40296923662015 and error = 0.00031176632000665393 at iteration 5943.
# Gradient descent partial with new b = -14.228352355582821, new m = 4.098312540401627, gradient size = 2.402786408409156 and error = 0.0003067794400015333 at iteration 5944.
# Gradient descent partial with new b = -14.230271041957254, new m = 4.098426755882345, gradient size = 2.402603594108516 and error = 0.00030183314103401194 at iteration 5945.
# Gradient descent partial with new b = -14.232189582349795, new m = 4.098540962673059, gradient size = 2.4024207937171758 and error = 0.00029692741389941946 at iteration 5946.
# Gradient descent partial with new b = -14.234107976771549, new m = 4.098655160774431, gradient size = 2.4022380072340717 and error = 0.0002920622493946003 at iteration 5947.
# Gradient descent partial with new b = -14.236026225233624, new m = 4.098769350187121, gradient size = 2.4020552346581465 and error = 0.0002872376383179403 at iteration 5948.
# Gradient descent partial with new b = -14.237944327747124, new m = 4.09888353091179, gradient size = 2.4018724759883416 and error = 0.0002824535714696754 at iteration 5949.
# Gradient descent partial with new b = -14.239862284323154, new m = 4.0989977029491, gradient size = 2.4016897312236063 and error = 0.0002777100396514498 at iteration 5950.
# Gradient descent partial with new b = -14.241780094972817, new m = 4.099111866299711, gradient size = 2.4015070003628707 and error = 0.0002730070336667538 at iteration 5951.
# Gradient descent partial with new b = -14.243697759707217, new m = 4.099226020964284, gradient size = 2.401324283405086 and error = 0.00026834454432053185 at iteration 5952.
# Gradient descent partial with new b = -14.245615278537455, new m = 4.099340166943481, gradient size = 2.4011415803491944 and error = 0.0002637225624194426 at iteration 5953.
# Gradient descent partial with new b = -14.247532651474632, new m = 4.099454304237962, gradient size = 2.4009588911941284 and error = 0.0002591410787717922 at iteration 5954.
# Gradient descent partial with new b = -14.249449878529848, new m = 4.099568432848388, gradient size = 2.4007762159388433 and error = 0.0002546000841874507 at iteration 5955.
# Gradient descent partial with new b = -14.251366959714202, new m = 4.099682552775419, gradient size = 2.4005935545822723 and error = 0.0002500995694779569 at iteration 5956.
# Gradient descent partial with new b = -14.253283895038795, new m = 4.099796664019717, gradient size = 2.4004109071233635 and error = 0.0002456395254564963 at iteration 5957.
# Gradient descent partial with new b = -14.25520068451472, new m = 4.099910766581941, gradient size = 2.4002282735610545 and error = 0.00024121994293781928 at iteration 5958.
# Gradient descent partial with new b = -14.257117328153079, new m = 4.100024860462753, gradient size = 2.400045653894291 and error = 0.00023684081273828343 at iteration 5959.
# Gradient descent partial with new b = -14.259033825964964, new m = 4.100138945662813, gradient size = 2.3998630481220182 and error = 0.00023250212567607221 at iteration 5960.
# Gradient descent partial with new b = -14.260950177961472, new m = 4.100253022182781, gradient size = 2.399680456243176 and error = 0.00022820387257071502 at iteration 5961.
# Gradient descent partial with new b = -14.262866384153698, new m = 4.100367090023318, gradient size = 2.399497878256703 and error = 0.00022394604424360472 at iteration 5962.
# Gradient descent partial with new b = -14.264782444552733, new m = 4.100481149185084, gradient size = 2.3993153141615515 and error = 0.00021972863151762106 at iteration 5963.
# Gradient descent partial with new b = -14.26669835916967, new m = 4.10059519966874, gradient size = 2.3991327639566586 and error = 0.0002155516252173274 at iteration 5964.
# Gradient descent partial with new b = -14.268614128015603, new m = 4.100709241474946, gradient size = 2.398950227640965 and error = 0.00021141501616891116 at iteration 5965.
# Gradient descent partial with new b = -14.27052975110162, new m = 4.100823274604362, gradient size = 2.398767705213421 and error = 0.00020731879520018368 at iteration 5966.
# Gradient descent partial with new b = -14.272445228438812, new m = 4.100937299057647, gradient size = 2.3985851966729657 and error = 0.0002032629531405245 at iteration 5967.
# Gradient descent partial with new b = -14.27436056003827, new m = 4.1010513148354635, gradient size = 2.398402702018543 and error = 0.00019924748082103053 at iteration 5968.
# Gradient descent partial with new b = -14.27627574591108, new m = 4.1011653219384705, gradient size = 2.3982202212491 and error = 0.0001952723690744024 at iteration 5969.
# Gradient descent partial with new b = -14.27819078606833, new m = 4.101279320367327, gradient size = 2.39803775436357 and error = 0.00019133760873485557 at iteration 5970.
# Gradient descent partial with new b = -14.280105680521109, new m = 4.1013933101226945, gradient size = 2.39785530136091 and error = 0.0001874431906384098 at iteration 5971.
# Gradient descent partial with new b = -14.2820204292805, new m = 4.101507291205232, gradient size = 2.3976728622400536 and error = 0.00018358910562256336 at iteration 5972.
# Gradient descent partial with new b = -14.28393503235759, new m = 4.1016212636156, gradient size = 2.397490436999952 and error = 0.0001797753445265438 at iteration 5973.
# Gradient descent partial with new b = -14.28584948976346, new m = 4.101735227354458, gradient size = 2.3973080256395427 and error = 0.00017600189819111291 at iteration 5974.
# Gradient descent partial with new b = -14.287763801509197, new m = 4.101849182422465, gradient size = 2.397125628157773 and error = 0.00017226875745874134 at iteration 5975.
# Gradient descent partial with new b = -14.289677967605881, new m = 4.101963128820282, gradient size = 2.396943244553586 and error = 0.000168575913173385 at iteration 5976.
# Gradient descent partial with new b = -14.291591988064594, new m = 4.102077066548568, gradient size = 2.3967608748259273 and error = 0.00016492335618082526 at iteration 5977.
# Gradient descent partial with new b = -14.293505862896417, new m = 4.102190995607982, gradient size = 2.396578518973741 and error = 0.000161311077328312 at iteration 5978.
# Gradient descent partial with new b = -14.295419592112431, new m = 4.102304915999185, gradient size = 2.3963961769959727 and error = 0.00015773906746473427 at iteration 5979.
# Gradient descent partial with new b = -14.297333175723715, new m = 4.102418827722835, gradient size = 2.3962138488915588 and error = 0.0001542073174406679 at iteration 5980.
# Gradient descent partial with new b = -14.299246613741346, new m = 4.102532730779593, gradient size = 2.3960315346594485 and error = 0.00015071581810827578 at iteration 5981.
# Gradient descent partial with new b = -14.301159906176402, new m = 4.1026466251701175, gradient size = 2.3958492342985935 and error = 0.00014726456032130984 at iteration 5982.
# Gradient descent partial with new b = -14.303073053039958, new m = 4.102760510895068, gradient size = 2.395666947807926 and error = 0.0001438535349352368 at iteration 5983.
# Gradient descent partial with new b = -14.304986054343091, new m = 4.102874387955104, gradient size = 2.395484675186397 and error = 0.00014048273280707908 at iteration 5984.
# Gradient descent partial with new b = -14.306898910096876, new m = 4.102988256350884, gradient size = 2.3953024164329593 and error = 0.0001371521447953877 at iteration 5985.
# Gradient descent partial with new b = -14.308811620312389, new m = 4.103102116083069, gradient size = 2.3951201715465436 and error = 0.00013386176176054785 at iteration 5986.
# Gradient descent partial with new b = -14.3107241850007, new m = 4.103215967152316, gradient size = 2.394937940526102 and error = 0.0001306115745643805 at iteration 5987.
# Gradient descent partial with new b = -14.312636604172882, new m = 4.103329809559286, gradient size = 2.3947557233705776 and error = 0.00012740157407044583 at iteration 5988.
# Gradient descent partial with new b = -14.314548877840007, new m = 4.103443643304637, gradient size = 2.394573520078913 and error = 0.000124231751143848 at iteration 5989.
# Gradient descent partial with new b = -14.316461006013146, new m = 4.1035574683890275, gradient size = 2.3943913306500657 and error = 0.00012110209665132511 at iteration 5990.
# Gradient descent partial with new b = -14.318372988703368, new m = 4.103671284813117, gradient size = 2.394209155082964 and error = 0.00011801260146126223 at iteration 5991.
# Gradient descent partial with new b = -14.320284825921743, new m = 4.103785092577565, gradient size = 2.394026993376566 and error = 0.00011496325644364756 at iteration 5992.
# Gradient descent partial with new b = -14.322196517679338, new m = 4.103898891683031, gradient size = 2.393844845529808 and error = 0.00011195405247007332 at iteration 5993.
# Gradient descent partial with new b = -14.32410806398722, new m = 4.104012682130171, gradient size = 2.3936627115416447 and error = 0.00010898498041379061 at iteration 5994.
# Gradient descent partial with new b = -14.326019464856456, new m = 4.104126463919646, gradient size = 2.393480591411012 and error = 0.00010605603114958614 at iteration 5995.
# Gradient descent partial with new b = -14.327930720298113, new m = 4.104240237052114, gradient size = 2.393298485136862 and error = 0.00010316719555401173 at iteration 5996.
# Gradient descent partial with new b = -14.329841830323254, new m = 4.104354001528234, gradient size = 2.3931163927181394 and error = 0.00010031846450512707 at iteration 5997.
# Gradient descent partial with new b = -14.331752794942943, new m = 4.104467757348665, gradient size = 2.392934314153791 and error = 9.750982888258375e-05 at iteration 5998.
# Gradient descent partial with new b = -14.333663614168245, new m = 4.104581504514065, gradient size = 2.3927522494427578 and error = 9.474127956772794e-05 at iteration 5999.
# Gradient descent partial with new b = -14.33557428801022, new m = 4.104695243025092, gradient size = 2.3925701985839916 and error = 9.201280744347032e-05 at iteration 6000.
# Gradient descent partial with new b = -14.337484816479929, new m = 4.104808972882405, gradient size = 2.392388161576436 and error = 8.932440339441209e-05 at iteration 6001.
# Gradient descent partial with new b = -14.339395199588434, new m = 4.104922694086663, gradient size = 2.3922061384190365 and error = 8.667605830668237e-05 at iteration 6002.
# Gradient descent partial with new b = -14.341305437346795, new m = 4.105036406638524, gradient size = 2.3920241291107405 and error = 8.406776306807525e-05 at iteration 6003.
# Gradient descent partial with new b = -14.34321552976607, new m = 4.105150110538645, gradient size = 2.391842133650491 and error = 8.149950856795221e-05 at iteration 6004.
# Gradient descent partial with new b = -14.345125476857318, new m = 4.105263805787686, gradient size = 2.391660152037238 and error = 7.897128569738406e-05 at iteration 6005.
# Gradient descent partial with new b = -14.347035278631594, new m = 4.105377492386305, gradient size = 2.391478184269932 and error = 7.648308534897311e-05 at iteration 6006.
# Gradient descent partial with new b = -14.348944935099958, new m = 4.105491170335159, gradient size = 2.391296230347509 and error = 7.403489841698233e-05 at iteration 6007.
# Gradient descent partial with new b = -14.350854446273463, new m = 4.105604839634907, gradient size = 2.391114290268922 and error = 7.162671579723263e-05 at iteration 6008.
# Gradient descent partial with new b = -14.352763812163163, new m = 4.105718500286207, gradient size = 2.3909323640331164 and error = 6.92585283872476e-05 at iteration 6009.
# Gradient descent partial with new b = -14.354673032780113, new m = 4.105832152289716, gradient size = 2.390750451639041 and error = 6.693032708605502e-05 at iteration 6010.
# Gradient descent partial with new b = -14.356582108135365, new m = 4.105945795646094, gradient size = 2.3905685530856404 and error = 6.46421027944461e-05 at iteration 6011.
# Gradient descent partial with new b = -14.358491038239972, new m = 4.106059430355998, gradient size = 2.390386668371867 and error = 6.239384641469615e-05 at iteration 6012.
# Gradient descent partial with new b = -14.360399823104986, new m = 4.106173056420086, gradient size = 2.3902047974966565 and error = 6.0185548850736344e-05 at iteration 6013.
# Gradient descent partial with new b = -14.362308462741456, new m = 4.106286673839014, gradient size = 2.3900229404589655 and error = 5.801720100808072e-05 at iteration 6014.
# Gradient descent partial with new b = -14.364216957160433, new m = 4.106400282613442, gradient size = 2.3898410972577384 and error = 5.58887937939258e-05 at iteration 6015.
# Gradient descent partial with new b = -14.366125306372965, new m = 4.106513882744027, gradient size = 2.3896592678919193 and error = 5.3800318117029714e-05 at iteration 6016.
# Gradient descent partial with new b = -14.368033510390099, new m = 4.106627474231426, gradient size = 2.389477452360461 and error = 5.175176488780071e-05 at iteration 6017.
# Gradient descent partial with new b = -14.369941569222883, new m = 4.106741057076298, gradient size = 2.3892956506623104 and error = 4.974312501821087e-05 at iteration 6018.
# Execution time for gradient descent solution: 1.312964677810669.
# Gradient descent finished with b = -14.369941569222883, m = 4.106741057076298 and error = 4.974312501821087e-05
# Execution time for closed linear regression: 5.650520324707031e-05.
# Closed linear regression finished with b = -39.44625667909617, m = 5.599482874119919 and error = 3.40724977255173
